#   inflating: images/maksssksksss840.png
#   inflating: images/maksssksksss841.png
#   inflating: images/maksssksksss842.png
#   inflating: images/maksssksksss843.png
#   inflating: images/maksssksksss844.png
#   inflating: images/maksssksksss845.png
#   inflating: images/maksssksksss846.png
#   inflating: images/maksssksksss847.png
#   inflating: images/maksssksksss848.png
#   inflating: images/maksssksksss849.png
#   inflating: images/maksssksksss85.png
#   inflating: images/maksssksksss850.png
#   inflating: images/maksssksksss851.png
#   inflating: images/maksssksksss852.png
#   inflating: images/maksssksksss86.png
#   inflating: images/maksssksksss87.png
#   inflating: images/maksssksksss88.png
#   inflating: images/maksssksksss89.png
#   inflating: images/maksssksksss9.png
#   inflating: images/maksssksksss90.png
#   inflating: images/maksssksksss91.png
#   inflating: images/maksssksksss92.png
#   inflating: images/maksssksksss93.png
#   inflating: images/maksssksksss94.png
#   inflating: images/maksssksksss95.png
#   inflating: images/maksssksksss96.png
#   inflating: images/maksssksksss97.png
#   inflating: images/maksssksksss98.png
#   inflating: images/maksssksksss99.png

# %%
# Nedded Libraries

# PyTorch
import torch 
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import models
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor, fasterrcnn_resnet50_fpn, fasterrcnn_mobilenet_v3_large_fpn
import albumentations as A

# Image processing
from PIL import Image, ImageDraw, ExifTags, ImageColor, ImageFont

# Image Plots
from matplotlib import pyplot as plt
import matplotlib.patches as patches

# Data managements
import numpy as np
import pandas as pd

# File interpretation
import os
import xml.etree.ElementTree as ET
import random

# Others
import time
from collections import Counter
from random import seed, randint
from datetime import datetime

# %% [markdown]
# Find Annotation Files¶

# %%
# Annotations directory path
ann_directory = '/content/annotations'

# List directory
ann_files = os.listdir(ann_directory)
print(ann_files)
# Out:
# ['maksssksksss482.xml', 'maksssksksss557.xml', 'maksssksksss126.xml', 'maksssksksss265.xml', 'maksssksksss776.xml', 'maksssksksss198.xml', 'maksssksksss780.xml', 'maksssksksss148.xml', 'maksssksksss82.xml', 'maksssksksss717.xml', 'maksssksksss479.xml', 'maksssksksss661.xml', 'maksssksksss750.xml', 'maksssksksss241.xml', 'maksssksksss464.xml', 'maksssksksss743.xml', 'maksssksksss639.xml', 'maksssksksss140.xml', 'maksssksksss317.xml', 'maksssksksss555.xml', 'maksssksksss813.xml', 'maksssksksss78.xml', 'maksssksksss376.xml', 'maksssksksss361.xml', 'maksssksksss380.xml', 'maksssksksss673.xml', 'maksssksksss607.xml', 'maksssksksss92.xml', 'maksssksksss237.xml', 'maksssksksss311.xml', 'maksssksksss177.xml', 'maksssksksss106.xml', 'maksssksksss576.xml', 'maksssksksss195.xml', 'maksssksksss615.xml', 'maksssksksss561.xml', 'maksssksksss721.xml', 'maksssksksss690.xml', 'maksssksksss435.xml', 'maksssksksss43.xml', 'maksssksksss320.xml', 'maksssksksss193.xml', 'maksssksksss440.xml', 'maksssksksss812.xml', 'maksssksksss396.xml', 'maksssksksss744.xml', 'maksssksksss335.xml', 'maksssksksss355.xml', 'maksssksksss272.xml', 'maksssksksss55.xml', 'maksssksksss386.xml', 'maksssksksss279.xml', 'maksssksksss129.xml', 'maksssksksss384.xml
ss641.png', 'maksssksksss399.png', 'maksssksksss95.png', 'maksssksksss203.png', 'maksssksksss701.png', 'maksssksksss224.png', 'maksssksksss693.png', 'maksssksksss135.png', 'maksssksksss84.png', 'maksssksksss204.png', 'maksssksksss100.png', 'maksssksksss46.png', 'maksssksksss554.png', 'maksssksksss301.png', 'maksssksksss240.png', 'maksssksksss560.png', 'maksssksksss297.png', 'maksssksksss797.png', 'maksssksksss752.png', 'maksssksksss169.png', 'maksssksksss152.png', 'maksssksksss263.png', 'maksssksksss388.png', 'maksssksksss111.png', 'maksssksksss649.png', 'maksssksksss80.png', 'maksssksksss528.png', 'maksssksksss664.png', 'maksssksksss337.png', 'maksssksksss816.png', 'maksssksksss121.png', 'maksssksksss255.png', 'maksssksksss573.png', 'maksssksksss167.png', 'maksssksksss81.png', 'maksssksksss629.png', 'maksssksksss595.png', 'maksssksksss817.png', 'maksssksksss141.png', 'maksssksksss392.png', 'maksssksksss737.png', 'maksssksksss480.png', 'maksssksksss516.png', 'maksssksksss470.png', 'maksssksksss47.png', 'maksssksksss711.png', 'maksssksksss694.png', 'maksssksksss343.png', 'maksssksksss852.png', 'maksssksksss571.png', 'maksssksksss369.png', 'maksssksksss367.png', 'maksssksksss281.png', 'maksssksksss164.png', 'maksssksksss764.png', 'maks ...

# %% [markdown]
# Helper Functions¶

# %%
def draw_bounding_boxes(img_tensor, target=None, prediction=None):
    """Draws bounding boxes in given images. Displays them

        Inputs:
          img:
            Image in tensor format.
          target:
            target dictionary containing bboxes list wit format -> [xmin, ymin, xmax, ymax]

        Returns:
          None
        """

    img = torchvision.transforms.ToPILImage()(img_tensor)

    # fetching the dimensions
    wid, hgt = img.size
    print(str(wid) + "x" + str(hgt))

    # Img to draw in
    draw = ImageDraw.Draw(img)

    if target:
        target_bboxes = target['boxes'].numpy().tolist()
        target_labels = decode_labels(target['labels'].numpy())

        for i in range(len(target_bboxes)):
            # Create Rectangle patches and add the patches to the axes
            draw.rectangle(target_bboxes[i], fill=None, outline='green', width=2)
            draw.text(target_bboxes[i][:2], target_labels[i], fill='green', font=None, anchor=None, spacing=4,
                      align='left', direction=None, features=None, language=None, stroke_width=0, stroke_fill=None,
                      embedded_color=False)

    if prediction:
        prediction_bboxes = prediction['boxes'].detach().cpu().numpy().tolist()
        prediction_labels = decode_labels(prediction['labels'].detach().cpu().numpy())
        for i in range(len(prediction_bboxes)):
            # Create Rectangle patches and add the patches to the axes
            draw.rectangle(prediction_bboxes[i], fill=None, outline='red', width=2)
            draw.text(prediction_bboxes[i][:2], prediction_labels[i], fill='red', font=None, anchor=None, spacing=4,
                      align='left', direction=None, features=None, language=None, stroke_width=0, stroke_fill=None,
                      embedded_color=False)

    display(img)

# %%
def encoded_labels(lst_labels):
    """Encodes label classes from string to integers.

        Labels are encoded accordingly:
            - background => 0
            - with_mask => 1
            - mask_weared_incorrect => 2
            - without_mask => 3

            Args:
              lst_labels:
                A list with classes in string format (e.g. ['with_mask', 'mask_weared_incorrect'...]).

            Returns:
              encoded:
                A list with integers that represent each class.
            """

    encoded=[]
    for label in lst_labels:
        if label == "with_mask":
            code = 1
        elif label == "mask_weared_incorrect":
            code = 2
        elif label == "without_mask":
            code = 3
        else:
            code = 0
        encoded.append(code)
    return encoded

# %%
def decode_labels(lst_labels):
    """
    Decode label classes from integers to strings.
    Labels are encoded accordingly:
        - background => 0
        - with_mask => 1
        - mask_weared_incorrect => 2
        - without_mask => 3

    Args:
      lst_labels:
        A list with classes in integer format (e.g. [1, 2, ...]).

    Returns:
        A list with strings that represent each class.
    """

    labels=[]
    for code in lst_labels:
        if code == 1:
            label = "with_mask"
        elif code == 2:
            label = "mask_weared_incorrect"
        elif code == 3:
            label = "without_mask"
        else:
            label = 'background'
        labels.append(label)
    return labels

# %%
def build_model(nclasses):
    """
    Builds model. Uses Faster R-CNN pre-trained on COCO dataset.

    Args:
      nclasses:
        number of classes

    Return:
      model: Faster R-CNN pre-trained model
    """
    # load pre-trained model on COCO
    model = fasterrcnn_mobilenet_v3_large_fpn(pretrained=True, min_size=400, max_size=700)

    # get the number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features

    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, nclasses)

    return model

# %%
def train_model(model, loader, optimizer, scheduler, epochs, device):
  """ 
    Inputs:
      - model
      - loader: Dataloader PyTorch object with training data
      - optimizer
      - scheduler
      - epochs
      - device

    Returns:
      - model
      - loss_list: list with mean loss per epoch. Epoch 1 is in idex 0.
    """
  # Create a loss list to keep epoch average loss
  loss_list = []
  # Epochs
  for epoch in range(epochs):
      print('Starting epoch...... {}/{} '.format(epoch + 1, epochs))
      iteration = 0
      loss_sub_list = []
      start = time.time()
      for images, targets in loader:
          # Agregate images in batch loader
          images = list(image.to(device) for image in images)

          # Agregate targets in batch loader
          targets = [{key: val.to(device) for key, val in target.items()} for target in targets]

          # Sets model to train mode (just a flag)
          model.train()

          # Output of model returns loss and detections
          optimizer.zero_grad()
          output = model(images, targets)

          # Calculate Cost
          losses = sum(loss for loss in output.values())
          loss_value = losses.item()
          loss_sub_list.append(loss_value)
          print('')

          # Update optimizer and learning rate
          losses.backward()
          optimizer.step()
          iteration += 1
          print('Iteration: {:d} --> Loss: {:.3f}'.format(iteration, loss_value))
          
      end = time.time()
      # update scheduler
      scheduler.step()
      # print the loss of epoch
      epoch_loss = np.mean(loss_sub_list)
      loss_list.append(epoch_loss)
      print('Epoch loss: {:.3f} , time used: ({:.1f}s)'.format(epoch_loss, end - start))
      
  return model, loss_list

# %%
def apply_nms(orig_prediction, iou_thresh):
    """
    Applies non max supression and eliminates low score bounding boxes.

      Args:
        orig_prediction: the model output. A dictionary containing element scores and boxes.
        iou_thresh: Intersection over Union threshold. Every bbox prediction with an IoU greater than this value
                      gets deleted in NMS.

      Returns:
        final_prediction: Resulting prediction
    """

    # torchvision returns the indices of the bboxes to keep
    keep = torchvision.ops.nms(orig_prediction['boxes'], orig_prediction['scores'], iou_thresh)

    # Keep indices from nms
    final_prediction = orig_prediction
    final_prediction['boxes'] = final_prediction['boxes'][keep]
    final_prediction['scores'] = final_prediction['scores'][keep]
    final_prediction['labels'] = final_prediction['labels'][keep]

    return final_prediction

# %%
def remove_low_score_bb(orig_prediction, score_thresh):
    """
    Eliminates low score bounding boxes.

    Args:
        orig_prediction: the model output. A dictionary containing element scores and boxes.
        score_thresh: Boxes with a lower confidence score than this value get deleted

    Returns:
        final_prediction: Resulting prediction
    """

    # Remove low confidence scores according to given threshold
    index_list_scores = []
    scores = orig_prediction['scores'].detach().cpu().numpy()
    for i in range(len(scores)):
        if scores[i] > score_thresh:
            index_list_scores.append(i)
    keep = torch.tensor(index_list_scores)

    # Keep indices from high score bb
    final_prediction = orig_prediction
    final_prediction['boxes'] = final_prediction['boxes'][keep]
    final_prediction['scores'] = final_prediction['scores'][keep]
    final_prediction['labels'] = final_prediction['labels'][keep]

    return final_prediction

# %%
def collate_fn(batch):
    # Collate function for Dataloader
    return tuple(zip(*batch))

# %%
def IOU(box1, box2):
    '''
    Intersection over Union - IoU
    *------------
    |   (x2min,y2min)
    |   *----------
    |   | ######| |
    ----|------* (x1max,y1max)
        |         |
        ----------

    Args:
        box1: [xmin,ymin,xmax,ymax]
        box2: [xmin,ymin,xmax,ymax]

    Returns:
        iou -> value of intersection over union of the 2 boxes

    '''

    # Compute coordinates of intersection
    xmin_inter = max(box1[0], box2[0])
    ymin_inter = max(box1[1], box2[1])
    xmax_inter = min(box1[2], box2[2])
    ymax_inter = min(box1[3], box2[3])

    # calculate area of intersection rectangle
    inter_area = max(0, xmax_inter - xmin_inter + 1) * max(0, ymax_inter - ymin_inter + 1) # FIXME why plus one?
 
    # calculate boxes areas
    area1 = (box1[2] - box1[0] + 1) * (box1[3] - box1[1] + 1)
    area2 = (box2[2] - box2[0] + 1) * (box2[3] - box2[1] + 1)
 
    # compute IoU
    iou = inter_area / float(area1 + area2 - inter_area)
    assert iou >= 0
    return iou

# %%
def compute_AP(ground_truth, predictions, iou_thresh=0.5, n_classes=4):
    """
    Calculates Average Precision across all classes.

    Args:
        ground_truth: list with ground-truth objects. Needs to have the following format: [sequence, frame, obj, [xmin, ymin, xmax, ymax], label, score]
        predictions: list with predictions objects. Needs to have the following format: [sequence, frame, obj, [xmin, ymin, xmax, ymax], label, score]
        iou_thresh: IoU to which a prediction compared to a ground-truth is considered right.
        n_classes: number of existent classes

    Returns:
        Average precision for the specified threshold.
    """
    # Initialize lists
    APs = []
    class_gt = []
    class_predictions = []

    # AP is computed for each class
    for c in range(n_classes):
        # Find gt and predictions of the class
        for gt in ground_truth:
            if gt[4] == c:
                class_gt.append(gt)
        for predict in predictions:
            if predict[4] == c:
                class_predictions.append(predict)

        # Create dict with array of zeros for bb in each image
        gt_amount_bb = Counter([gt[1] for gt in class_gt])
        for key, val in gt_amount_bb.items():
            gt_amount_bb[key] = np.zeros(val)

        # Sort class predictions by their score
        class_predictions = sorted(class_predictions, key=lambda x: x[5], reverse=True)

        # Create arrays for Positives (True and False)
        TP = np.zeros(len(class_predictions))
        FP = np.zeros(len(class_predictions))
        # Number of true boxes
        truth = len(class_gt)

        # Initializing aux variables
        epsilon = 1e-6

        # Iterate over predictions in each image and compare with ground truth
        for predict_idx, prediction in enumerate(class_predictions):
            # Filter prediction image ground truths
            image_gt = [obj for obj in class_gt if obj[1] == prediction[1]]

            # Initializing aux variables
            best_iou = -1
            best_gt_iou_idx = -1

            # Iterate through image ground truths and calculate IoUs
            for gt_idx, gt in enumerate(image_gt):
                iou = IOU(prediction[3], gt[3])
                if iou > best_iou:
                    best_iou = iou
                    best_gt_iou_idx = gt_idx

            # If the best IoU is greater that thresh than an TP prediction has been found
            if best_iou > iou_thresh and best_gt_iou_idx > -1:
                # Check if gt box was already covered
                if  gt_amount_bb[prediction[1]][best_gt_iou_idx] == 0:
                    gt_amount_bb[prediction[1]][best_gt_iou_idx] = 1  # set as covered
                    TP[predict_idx] = 1  # Count as true positive
                else:
                    FP[predict_idx] = 1
            else:
                FP[predict_idx] = 1

        # Calculate recall and precision
        TP_cumsum = np.cumsum(TP)
        FP_cumsum = np.cumsum(FP)
        recall = np.append([0], TP_cumsum / (truth + epsilon))
        precision = np.append([1], np.divide(TP_cumsum, (TP_cumsum + FP_cumsum + epsilon)))

        # Calculate the area precision/recall and add to list
        APs.append(np.trapz(precision, recall))

    return sum(APs)/len(APs)  # average of class precisions


def compute_mAP(ground_truth, predictions, n_classes):
    """
    Calls AP computation for different levels of IoUs, [0.5:.05:0.95].

    Args:
        ground_truth: list with ground-truth objects. Needs to have the following format: [sequence, frame, obj, [xmin, ymin, xmax, ymax], label, score]
        predictions: list with predictions objects. Needs to have the following format: [sequence, frame, obj, [xmin, ymin, xmax, ymax], label, score]
        n_classes: number of existent classes.

    Returns:
        mAp and list with APs for each IoU threshold.
    """
    # return mAP
    APs = [compute_AP(ground_truth, predictions, iou_thresh, n_classes) for iou_thresh in np.arange(0.5, 1.0, 0.05)]
    return np.mean(APs), APs

# %%
@torch.no_grad()
def evaluate(model, data_loader, device, sequences=1):
    """
    Evaluates model mAP for IoU range of [0.5:.05:0.95].

    Args:
        model: -
        data_loader: -
        device: -
        sequences: the number of sequences of images to pass, if any

    Returns:
        mAP and AP list for each IoU threshold in range [0.5:.05:0.95]
    """

    # Set evaluation mode flag
    model.eval()
    # Create list with all object detection -> [set, frame, obj, [xmin,ymin,xmax,ymax], label, score]
    ground_truth = []
    predictions = []

    # Gather all targets and outputs on test set
    for image, targets in data_loader:
        image = [img.to(device) for img in image]
        outputs = model(image)
        for idx in range(len(outputs)):
            outputs[idx] = apply_nms(outputs[idx], iou_thresh=0.5)

        # create list for targets and outputs to pass to compute_mAP()
        # lists have the following structure:  [sequence, frame, obj_idx, [xmin, ymin, xmax, ymax], label, score]
        for s in range(sequences):
            obj_gt = 0
            obj_target = 0
            for out, target in zip(outputs, targets):

                for i in range(len(target['boxes'])):
                    ground_truth.append([s, target['image_id'].detach().cpu().numpy()[0], obj_target,
                                         target['boxes'].detach().cpu().numpy()[i],
                                         target['labels'].detach().cpu().numpy()[i], 1])
                    obj_target += 1

                for j in range(len(out['boxes'])):
                    predictions.append([s, target['image_id'].detach().cpu().numpy()[0], obj_gt,
                                        out['boxes'].detach().cpu().numpy()[j],
                                        out['labels'].detach().cpu().numpy()[j],
                                        out['scores'].detach().cpu().numpy()[j]])
                    obj_gt += 1

    mAP, AP = compute_mAP(ground_truth, predictions, n_classes=4)
    print("mAP:{:.3f}".format(mAP))
    for ap_metric, iou in zip(AP, np.arange(0.5, 1, 0.05)):
        print("\tAP at IoU level [{:.2f}]: {:.3f}".format(iou, ap_metric))

    return mAP, AP

# %% [markdown]
# Create Dataset Class¶

# %%
# Create dataset object
class MyDataset(Dataset):

    # Constructor
    def __init__(self, ann_dir, img_dir, transform=None, mode='train'):

        # Image directories
        self.ann_dir = ann_dir
        self.img_dir = img_dir

        # The transform is goint to be used on image
        self.transform = transform

        # Create dataframe to hold info
        self.data = pd.DataFrame(columns=['Filename', 'BoundingBoxes', 'Labels', 'Area', 'N_Objects'])

        # Append rows with image filename and respective bounding boxes to the df
        for file in enumerate(os.listdir(img_dir)):

            # Find image annotation file
            ann_file_path = os.path.join(ann_dir, file[1][:-4]) + '.xml'

            # Read XML file and return bounding boxes and class attributes
            objects = self.read_XML_classf(ann_file_path)

            # Create list of labels in an image
            list_labels = encoded_labels(objects[0]['labels'])

            # Create list of bounding boxes in an image
            list_bb = []
            list_area = []
            n_obj = len(objects[0]['objects'])
            for i in objects[0]['objects']:
                list = [i['xmin'], i['ymin'], i['xmax'], i['ymax']]
                list_bb.append(list)
                list_area.append((i['xmax'] - i['xmin']) * (i['ymax'] - i['ymin']))

            # Create dataframe object with row containing [(Image file name),(Bounding Box List)]
            df = pd.DataFrame([[file[1], list_bb, list_labels, list_area, n_obj]],
                              columns=['Filename', 'BoundingBoxes', 'Labels', 'Area', 'N_Objects'])
            self.data = self.data.append(df)

        if mode == 'train':
            self.data = self.data[:680]
        elif mode == 'validation':
            self.data = self.data[680:700]
        elif mode == 'test':
            self.data = self.data[700:850]

        # Number of images in dataset
        self.len = self.data.shape[0]

        # Get the length

    def __len__(self):
        return self.len

    # Getter
    def __getitem__(self, idx):

        # Image file path
        img_name = os.path.join(self.img_dir, self.data.iloc[idx, 0])

        # Open image file and tranform to tensor
        img = Image.open(img_name).convert('RGB')

        # Get bounding box coordinates
        bbox = torch.tensor(self.data.iloc[idx, 1])

        # Get labels
        labels = torch.tensor(self.data.iloc[idx, 2])

        # Get bounding box areas
        area = torch.tensor(self.data.iloc[idx, 3])

        # If any, aplly tranformations to image and bounding box mask
        if self.transform:
            # Convert PIL image to numpy array
            img = np.array(img)
            # Apply transformations
            transformed = self.transform(image=img, bboxes=bbox)
            # Convert numpy array to PIL Image
            img = Image.fromarray(transformed['image'])
            # Get transformed bb
            bbox = torch.tensor(transformed['bboxes'])

        # suppose all instances are not crowd
        num_objs = self.data.iloc[idx, 4]
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        # Transform img to tensor
        img = torchvision.transforms.ToTensor()(img)

        # Build Targer dict
        target= {"boxes": bbox, "labels": labels, "image_id": torch.tensor([idx]), "area": area, "iscrowd": iscrowd}

        return img, target

    # XML reader -> returns dictionary with image bounding boxes sizes
    def read_XML_classf(self, ann_file_path):
        bboxes = [{
            'file': ann_file_path,
            'labels': [],
            'objects': []
        }]

        # Reading XML file objects and print Bounding Boxes
        tree = ET.parse(ann_file_path)
        root = tree.getroot()
        objects = root.findall('object')

        for obj in objects:
            # label
            label = obj.find('name').text
            bboxes[0]['labels'].append(label)

            # bbox dimensions
            bndbox = obj.find('bndbox')
            xmin = int(bndbox.find('xmin').text)
            ymin = int(bndbox.find('ymin').text)
            xmax = int(bndbox.find('xmax').text)
            ymax = int(bndbox.find('ymax').text)
            bboxes[0]['objects'].append({'xmin': xmin, 'ymin': ymin, 'xmax': xmax, 'ymax': ymax})

        return bboxes

# %% [markdown]
# Create Data Pipeline

# %%
# Create Data Pipeline

# Training Data
dataset_train = MyDataset(ann_directory,img_directory, mode = 'train')
loader_train = DataLoader(dataset_train, batch_size=4, shuffle=True, collate_fn=collate_fn)
# Validation Data
dataset_validation = MyDataset(ann_directory,img_directory, mode = 'validation')
loader_val = DataLoader(dataset_validation, batch_size=4, shuffle=True, collate_fn=collate_fn)
# Test Data
dataset_test = MyDataset(ann_directory,img_directory, mode = 'test')
loader_test = DataLoader(dataset_test, batch_size=4, shuffle=True, collate_fn=collate_fn)

# %%
# pick one image from the train set
img, target = dataset_train[70]
draw_bounding_boxes(img, target)
# Out:
# 301x400
# <PIL.Image.Image image mode=RGB size=301x400 at 0x7FD35C30CF90>

# %% [markdown]
# Setting up the Faster R-CNN Model¶

# %%
# Setting up GPU device
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# Nº of classes: background, with_mask, mask_weared_incorrect, without_mask and build model (faster r-cnn)
num_classes = 4 
model = build_model(num_classes)

model = model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_mobilenet_v3_large_fpn-fb6a3cc7.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_mobilenet_v3_large_fpn-fb6a3cc7.pth
#   0%|          | 0.00/74.2M [00:00<?, ?B/s]

# %%
# Set Hyper-parameters

# Network params
params = [p for p in model.parameters() if p.requires_grad]

# Optimizers
optimizer = torch.optim.Adam(params, lr=0.0001)
#optimizer = torch.optim.SGD(params, lr=0.005)

# Learning Rate, lr decreases to half every 2 epochs 
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.5)

# Number of epochs to perform
epochs=20

# %% [markdown]
# Train the model¶

# %%
pip install git+https://github.com/gautamchitnis/cocoapi.git@cocodataset-master#subdirectory=PythonAPI
# Out:
# Collecting git+https://github.com/gautamchitnis/cocoapi.git@cocodataset-master#subdirectory=PythonAPI
#   Cloning https://github.com/gautamchitnis/cocoapi.git (to revision cocodataset-master) to /tmp/pip-req-build-fqocigs6
#   Running command git clone -q https://github.com/gautamchitnis/cocoapi.git /tmp/pip-req-build-fqocigs6
#   Running command git checkout -b cocodataset-master --track origin/cocodataset-master
#   Switched to a new branch 'cocodataset-master'
#   Branch 'cocodataset-master' set up to track remote branch 'cocodataset-master' from 'origin'.
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp37-cp37m-linux_x86_64.whl size=264518 sha256=61117ce3dd4a646e5ec21485489819c35b741a4ab278a621c7382b8444264d42
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4udpvqhu/wheels/6e/c9/59/56484d4d5ac1ab292a452b4c3870277256551505954fc4a1db
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.4
#     Uninstalling pycocotools-2.0.4:
#       Successfully uninstalled pycocotools-2.0.4
# Successfully installed pycocotools-2.0

# %%
# !git clone https://github.com/pytorch/vision.git
# %cd vision
# !git checkout v0.3.0

# !cp references/detection/utils.py ../
# !cp references/detection/transforms.py ../
# !cp references/detection/coco_eval.py ../
# !cp references/detection/engine.py ../
# !cp references/detection/coco_utils.py ../
# %cd ..
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 130071, done.
# remote: Total 130071 (delta 0), reused 0 (delta 0), pack-reused 130071
# Receiving objects: 100% (130071/130071), 252.55 MiB | 26.60 MiB/s, done.
# Resolving deltas: 100% (114016/114016), done.
# /content/vision
# Note: checking out 'v0.3.0'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at be376084d version check against PyTorch's CUDA version
# /content

# %%
from engine import train_one_epoch
# Training
for epoch in range(epochs):
    # train for one epoch, printing every 50 iterations
    train_one_epoch(model, optimizer, loader_train, device, epoch, print_freq=20)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, loader_val, device=device)
# Out:
# Epoch: [0]  [  0/170]  eta: 0:02:19  lr: 0.000001  loss: 1.7594 (1.7594)  loss_classifier: 1.5108 (1.5108)  loss_box_reg: 0.0155 (0.0155)  loss_objectness: 0.2229 (0.2229)  loss_rpn_box_reg: 0.0103 (0.0103)  time: 0.8215  data: 0.0719  max mem: 656
# Epoch: [0]  [ 20/170]  eta: 0:01:01  lr: 0.000013  loss: 1.6022 (1.5853)  loss_classifier: 1.3079 (1.2749)  loss_box_reg: 0.0933 (0.0944)  loss_objectness: 0.1677 (0.1831)  loss_rpn_box_reg: 0.0163 (0.0330)  time: 0.3913  data: 0.0809  max mem: 989
# Epoch: [0]  [ 40/170]  eta: 0:00:55  lr: 0.000024  loss: 0.5831 (1.1435)  loss_classifier: 0.3250 (0.8421)  loss_box_reg: 0.1231 (0.1157)  loss_objectness: 0.0993 (0.1536)  loss_rpn_box_reg: 0.0179 (0.0320)  time: 0.4504  data: 0.1314  max mem: 989
# Epoch: [0]  [ 60/170]  eta: 0:00:46  lr: 0.000036  loss: 0.5434 (0.9718)  loss_classifier: 0.2628 (0.6670)  loss_box_reg: 0.2057 (0.1610)  loss_objectness: 0.0437 (0.1183)  loss_rpn_box_reg: 0.0111 (0.0255)  time: 0.4042  data: 0.1175  max mem: 1011
# Epoch: [0]  [ 80/170]  eta: 0:00:36  lr: 0.000048  loss: 0.5240 (0.8641)  loss_classifier: 0.2192 (0.5620)  loss_box_reg: 0.2205 (0.1784)  loss_objectness: 0.0341 (0.0992)  loss_rpn_box_reg: 0.0125 (0.0244)  time: 0.3408  data: 0.0624  max mem: 1011
# Epoch: [0]  [100/170]  eta: 0:00:26  lr: 0.000060  loss: 0.6390 (0.8286)  loss_classifier: 0.2734 (0.5089)  loss_box_reg: 0.3427 (0.2118)  loss_objectness: 0.0202 (0.0856)  loss_rpn_box_reg: 0.0068 (0.0223)  time: 0.3177  data: 0.0644  max mem: 1011
# Epoch: [0]  [120/170]  eta: 0:00:18  lr: 0.000072  loss: 0.7006 (0.8149)  loss_classifier: 0.2705 (0.4748)  loss_box_reg: 0.3380 (0.2425)  loss_objectness: 0.0248 (0.0765)  loss_rpn_box_reg: 0.0114 (0.0212)  time: 0.3159  data: 0.0653  max mem: 1011
# Epoch: [0]  [140/170]  eta: 0:00:10  lr: 0.000083  loss: 0.7316 (0.8044)  loss_classifier: 0.2942 (0.4492)  loss_box_reg: 0.3966 (0.2640)  loss_objectness: 0.0286 (0.0700)  loss_rpn_box_reg: 0.0094 (0.0212)  time: 0.3170  data: 0.0637  max mem: 1011
# Epoch: [0]  [160/170]  eta: 0:00:03  lr: 0.000095  loss: 0.8047 (0.8087)  loss_classifier: 0.3360 (0.4362)  loss_box_reg: 0.4539 (0.2886)  loss_objectness: 0.0170 (0.0640)  loss_rpn_box_reg: 0.0101 (0.0199)  time: 0.3079  data: 0.0630  max mem: 1011
# Epoch: [0]  [169/170]  eta: 0:00:00  lr: 0.000100  loss: 0.8582 (0.8110)  loss_classifier: 0.3392 (0.4327)  loss_box_reg: 0.4612 (0.2972)  loss_objectness: 0.0164 (0.0618)  loss_rpn_box_reg: 0.0071 (0.0194)  time: 0.3053  data: 0.0632  max mem: 1011
# Epoch: [0] Total time: 0:01:00 (0.3561 s / it)
# mAP:0.169
# 	AP at IoU level [0.50]: 0.367
# 	AP at IoU level [0.55]: 0.349
# 	AP at IoU level [0.60]: 0.297
# 	AP at IoU level [0.65]: 0.267
# 	AP at IoU level [0.70]: 0.223
# 	AP at IoU level [0.75]: 0.100
# 	AP at IoU level [0.80]: 0.052
# 	AP at IoU level [0.85]: 0.027
# 	AP at IoU level [0.90]: 0.007
# 	AP at IoU level [0.95]: 0.000
# Epoch: [1]  [  0/170]  eta: 0:01:08  lr: 0.000100  loss: 0.7271 (0.7271)  loss_classifier: 0.2608 (0.2608)  loss_box_reg: 0.4527 (0.4527)  loss_objectness: 0.0106 (0.0106)  loss_rpn_box_reg: 0.0030 (0.0030)  time: 0.4025  data: 0.0752  max mem: 1011
# Epoch: [1]  [ 20/170]  eta: 0:00:45  lr: 0.000100  loss: 0.8271 (0.8304)  loss_classifier: 0.3221 (0.3188)  loss_box_reg: 0.4690 (0.4813)  loss_objectness: 0.0170 (0.0199)  loss_rpn_box_reg: 0.0066 (0.0104)  time: 0.2987  data: 0.0622  max mem: 1011
# Epoch: [1]  [ 40/170]  eta: 0:00:39  lr: 0.000100  loss: 0.6961 (0.7794)  loss_classifier: 0.2696 (0.2957)  loss_box_reg: 0.3825 (0.4552)  loss_objectness: 0.0139 (0.0187)  loss_rpn_box_reg: 0.0062 (0.0098)  time: 0.2976  data: 0.0611  max mem: 1011
# Epoch: [1]  [ 60/170]  eta: 0:00:33  lr: 0.000100  loss: 0.7561 (0.7872)  loss_classifier: 0.2907 (0.2963)  loss_box_reg: 0.4356 (0.4627)  loss_objectness: 0.0164 (0.0182)  loss_rpn_box_reg: 0.0088 (0.0101)  time: 0.3001  data: 0.0655  max mem: 1011
# Epoch: [1]  [ 80/170]  eta: 0:00:27  lr: 0.000100  loss: 0.6882 (0.7750)  loss_classifier: 0.2769 (0.2981)  loss_box_reg: 0.3975 (0.4462)  loss_objectness: 0.0131 (0.0190)  loss_rpn_box_reg: 0.0084 (0.0117)  time: 0.3056  data: 0.0637  max mem: 1011
# Epoch: [1]  [100/170]  eta: 0:00:20  lr: 0.000100  loss: 0.8516 (0.8075)  loss_classifier: 0.3157 (0.3073)  loss_box_reg: 0.5223 (0.4699)  loss_objectness: 0.0079 (0.0184)  loss_rpn_box_reg: 0.0043 (0.0119)  time: 0.2828  data: 0.0609  max mem: 1011
# Epoch: [1]  [120/170]  eta: 0:00:14  lr: 0.000100  loss: 0.8016 (0.8056)  loss_classifier: 0.3243 (0.3072)  loss_box_reg: 0.4110 (0.4663)  loss_objectness: 0.0163 (0.0190)  loss_rpn_box_reg: 0.0101 (0.0132)  time: 0.2957  data: 0.0623  max mem: 1011
# Epoch: [1]  [140/170]  eta: 0:00:08  lr: 0.000100  loss: 0.6153 (0.7849)  loss_classifier: 0.2554 (0.3001)  loss_box_reg: 0.3441 (0.4517)  loss_objectness: 0.0234 (0.0199)  loss_rpn_box_reg: 0.0122 (0.0132)  time: 0.3094  data: 0.0627  max mem: 1011
# Epoch: [1]  [160/170]  eta: 0:00:02  lr: 0.000100  loss: 0.6868 (0.7756)  loss_classifier: 0.2329 (0.2959)  loss_box_reg: 0.4109 (0.4476)  loss_objectness: 0.0110 (0.0193)  loss_rpn_box_reg: 0.0061 (0.0128)  time: 0.2877  data: 0.0574  max mem: 1011
# Epoch: [1]  [169/170]  eta: 0:00:00  lr: 0.000100  loss: 0.6708 (0.7719)  loss_classifier: 0.2309 (0.2948)  loss_box_reg: 0.3777 (0.4453)  loss_objectness: 0.0097 (0.0191)  loss_rpn_box_reg: 0.0059 (0.0128)  time: 0.3225  data: 0.0848  max mem: 1011
# Epoch: [1] Total time: 0:00:51 (0.3017 s / it)
# mAP:0.201
# 	AP at IoU level [0.50]: 0.435
# 	AP at IoU level [0.55]: 0.404
# 	AP at IoU level [0.60]: 0.354
# 	AP at IoU level [0.65]: 0.289
# 	AP at IoU level [0.70]: 0.245
# 	AP at IoU level [0.75]: 0.199
# 	AP at IoU level [0.80]: 0.077
# 	AP at IoU level [0.85]: 0.010
# 	AP at IoU level [0.90]: 0.000
# 	AP at IoU level [0.95]: 0.000
# Epoch: [2]  [  0/170]  eta: 0:01:15  lr: 0.000050  loss: 0.5869 (0.5869)  loss_classifier: 0.2474 (0.2474)  loss_box_reg: 0.2856 (0.2856)  loss_objectness: 0.0375 (0.0375)  loss_rpn_box_reg: 0.0164 (0.0164)  time: 0.4415  data: 0.0572  max mem: 1011
# Epoch: [2]  [ 20/170]  eta: 0:00:45  lr: 0.000050  loss: 0.5885 (0.6179)  loss_classifier: 0.2440 (0.2494)  loss_box_reg: 0.3368 (0.3354)  loss_objectness: 0.0144 (0.0183)  loss_rpn_box_reg: 0.0083 (0.0147)  time: 0.2964  data: 0.0605  max mem: 1011
# Epoch: [2]  [ 40/170]  eta: 0:00:38  lr: 0.000050  loss: 0.7968 (0.7352)  loss_classifier: 0.2804 (0.2823)  loss_box_reg: 0.4843 (0.4218)  loss_objectness: 0.0108 (0.0181)  loss_rpn_box_reg: 0.0078 (0.0130)  time: 0.2861  data: 0.0606  max mem: 1011
# Epoch: [2]  [ 60/170]  eta: 0:00:32  lr: 0.000050  loss: 0.7285 (0.7422)  loss_classifier: 0.2656 (0.2840)  loss_box_reg: 0.4334 (0.4301)  loss_objectness: 0.0106 (0.0166)  loss_rpn_box_reg: 0.0075 (0.0115)  time: 0.2878  data: 0.0617  max mem: 1011
# Epoch: [2]  [ 80/170]  eta: 0:00:26  lr: 0.000050  loss: 0.7231 (0.7491)  loss_classifier: 0.2974 (0.2893)  loss_box_reg: 0.4223 (0.4333)  loss_objectness: 0.0087 (0.0158)  loss_rpn_box_reg: 0.0057 (0.0106)  time: 0.2832  data: 0.0623  max mem: 1011
# Epoch: [2]  [100/170]  eta: 0:00:20  lr: 0.000050  loss: 0.7054 (0.7434)  loss_classifier: 0.2387 (0.2835)  loss_box_reg: 0.4542 (0.4352)  loss_objectness: 0.0083 (0.0148)  loss_rpn_box_reg: 0.0043 (0.0099)  time: 0.2763  data: 0.0621  max mem: 1011
# Epoch: [2]  [120/170]  eta: 0:00:14  lr: 0.000050  loss: 0.6720 (0.7404)  loss_classifier: 0.2286 (0.2794)  loss_box_reg: 0.4284 (0.4358)  loss_objectness: 0.0133 (0.0150)  loss_rpn_box_reg: 0.0061 (0.0102)  time: 0.2869  data: 0.0607  max mem: 1011
# Epoch: [2]  [140/170]  eta: 0:00:08  lr: 0.000050  loss: 0.7515 (0.7450)  loss_classifier: 0.2863 (0.2797)  loss_box_reg: 0.4490 (0.4395)  loss_objectness: 0.0100 (0.0150)  loss_rpn_box_reg: 0.0040 (0.0108)  time: 0.2906  data: 0.0609  max mem: 1011
# Epoch: [2]  [160/170]  eta: 0:00:02  lr: 0.000050  loss: 0.6370 (0.7416)  loss_classifier: 0.2223 (0.2754)  loss_box_reg: 0.3905 (0.4415)  loss_objectness: 0.0102 (0.0146)  loss_rpn_box_reg: 0.0049 (0.0102)  time: 0.2822  data: 0.0619  max mem: 1011
# Epoch: [2]  [169/170]  eta: 0:00:00  lr: 0.000050  loss: 0.7347 (0.7511)  loss_classifier: 0.2386 (0.2781)  loss_box_reg: 0.4854 (0.4484)  loss_objectness: 0.0115 (0.0145)  loss_rpn_box_reg: 0.0065 (0.0101)  time: 0.2828  data: 0.0640  max mem: 1011
# Epoch: [2] Total time: 0:00:48 (0.2868 s / it)
# mAP:0.228
# 	AP at IoU level [0.50]: 0.499
# 	AP at IoU level [0.55]: 0.447
# 	AP at IoU level [0.60]: 0.394
# 	AP at IoU level [0.65]: 0.332
# 	AP at IoU level [0.70]: 0.275
# 	AP at IoU level [0.75]: 0.191
# 	AP at IoU level [0.80]: 0.081
# 	AP at IoU level [0.85]: 0.050
# 	AP at IoU level [0.90]: 0.008
# 	AP at IoU level [0.95]: 0.000
# Epoch: [3]  [  0/170]  eta: 0:01:00  lr: 0.000050  loss: 0.7324 (0.7324)  loss_classifier: 0.2313 (0.2313)  loss_box_reg: 0.4867 (0.4867)  loss_objectness: 0.0086 (0.0086)  loss_rpn_box_reg: 0.0058 (0.0058)  time: 0.3532  data: 0.0668  max mem: 1011
# Epoch: [3]  [ 20/170]  eta: 0:00:43  lr: 0.000050  loss: 0.7008 (0.7257)  loss_classifier: 0.2499 (0.2742)  loss_box_reg: 0.4042 (0.4315)  loss_objectness: 0.0092 (0.0114)  loss_rpn_box_reg: 0.0041 (0.0087)  time: 0.2837  data: 0.0620  max mem: 1011
# Epoch: [3]  [ 40/170]  eta: 0:00:36  lr: 0.000050  loss: 0.6702 (0.6935)  loss_classifier: 0.1685 (0.2446)  loss_box_reg: 0.4472 (0.4294)  loss_objectness: 0.0069 (0.0117)  loss_rpn_box_reg: 0.0041 (0.0078)  time: 0.2792  data: 0.0657  max mem: 1011
# Epoch: [3]  [ 60/170]  eta: 0:00:31  lr: 0.000050  loss: 0.8209 (0.7304)  loss_classifier: 0.2634 (0.2568)  loss_box_reg: 0.4807 (0.4544)  loss_objectness: 0.0070 (0.0114)  loss_rpn_box_reg: 0.0038 (0.0079)  time: 0.2809  data: 0.0621  max mem: 1011
# Epoch: [3]  [ 80/170]  eta: 0:00:25  lr: 0.000050  loss: 0.7033 (0.7237)  loss_classifier: 0.2711 (0.2593)  loss_box_reg: 0.4044 (0.4440)  loss_objectness: 0.0113 (0.0121)  loss_rpn_box_reg: 0.0068 (0.0083)  time: 0.2906  data: 0.0638  max mem: 1011
# Epoch: [3]  [100/170]  eta: 0:00:20  lr: 0.000050  loss: 0.6881 (0.7157)  loss_classifier: 0.2718 (0.2594)  loss_box_reg: 0.3983 (0.4346)  loss_objectness: 0.0110 (0.0128)  loss_rpn_box_reg: 0.0048 (0.0088)  time: 0.2909  data: 0.0636  max mem: 1011
# Epoch: [3]  [120/170]  eta: 0:00:14  lr: 0.000050  loss: 0.7337 (0.7170)  loss_classifier: 0.2276 (0.2585)  loss_box_reg: 0.4662 (0.4360)  loss_objectness: 0.0085 (0.0131)  loss_rpn_box_reg: 0.0057 (0.0095)  time: 0.2860  data: 0.0641  max mem: 1011
# Epoch: [3]  [140/170]  eta: 0:00:08  lr: 0.000050  loss: 0.6548 (0.7130)  loss_classifier: 0.2212 (0.2547)  loss_box_reg: 0.4170 (0.4368)  loss_objectness: 0.0083 (0.0125)  loss_rpn_box_reg: 0.0032 (0.0090)  time: 0.2782  data: 0.0641  max mem: 1011
# Epoch: [3]  [160/170]  eta: 0:00:02  lr: 0.000050  loss: 0.7090 (0.7140)  loss_classifier: 0.2269 (0.2566)  loss_box_reg: 0.3793 (0.4350)  loss_objectness: 0.0087 (0.0131)  loss_rpn_box_reg: 0.0070 (0.0093)  time: 0.2950  data: 0.0653  max mem: 1011
# Epoch: [3]  [169/170]  eta: 0:00:00  lr: 0.000050  loss: 0.6066 (0.7111)  loss_classifier: 0.2163 (0.2552)  loss_box_reg: 0.3685 (0.4336)  loss_objectness: 0.0087 (0.0131)  loss_rpn_box_reg: 0.0052 (0.0092)  time: 0.2875  data: 0.0649  max mem: 1011
# Epoch: [3] Total time: 0:00:48 (0.2863 s / it)
# mAP:0.269
# 	AP at IoU level [0.50]: 0.506
# 	AP at IoU level [0.55]: 0.484
# 	AP at IoU level [0.60]: 0.418
# 	AP at IoU level [0.65]: 0.370
# 	AP at IoU level [0.70]: 0.321
# 	AP at IoU level [0.75]: 0.259
# 	AP at IoU level [0.80]: 0.187
# 	AP at IoU level [0.85]: 0.133
# 	AP at IoU level [0.90]: 0.017
# 	AP at IoU level [0.95]: 0.000
# Epoch: [4]  [  0/170]  eta: 0:01:06  lr: 0.000025  loss: 0.6193 (0.6193)  loss_classifier: 0.2164 (0.2164)  loss_box_reg: 0.3849 (0.3849)  loss_objectness: 0.0089 (0.0089)  loss_rpn_box_reg: 0.0092 (0.0092)  time: 0.3915  data: 0.0761  max mem: 1011
# Epoch: [4]  [ 20/170]  eta: 0:00:44  lr: 0.000025  loss: 0.6527 (0.6484)  loss_classifier: 0.2166 (0.2374)  loss_box_reg: 0.4033 (0.3872)  loss_objectness: 0.0123 (0.0141)  loss_rpn_box_reg: 0.0052 (0.0096)  time: 0.2888  data: 0.0652  max mem: 1011
# Epoch: [4]  [ 40/170]  eta: 0:00:37  lr: 0.000025  loss: 0.6900 (0.6632)  loss_classifier: 0.2409 (0.2404)  loss_box_reg: 0.3992 (0.4029)  loss_objectness: 0.0090 (0.0123)  loss_rpn_box_reg: 0.0031 (0.0075)  time: 0.2817  data: 0.0644  max mem: 1011
# Epoch: [4]  [ 60/170]  eta: 0:00:31  lr: 0.000025  loss: 0.6717 (0.6769)  loss_classifier: 0.2371 (0.2451)  loss_box_reg: 0.4202 (0.4104)  loss_objectness: 0.0058 (0.0130)  loss_rpn_box_reg: 0.0035 (0.0084)  time: 0.2803  data: 0.0647  max mem: 1011
# Epoch: [4]  [ 80/170]  eta: 0:00:25  lr: 0.000025  loss: 0.6513 (0.6745)  loss_classifier: 0.2072 (0.2398)  loss_box_reg: 0.4208 (0.4146)  loss_objectness: 0.0077 (0.0121)  loss_rpn_box_reg: 0.0054 (0.0080)  time: 0.2790  data: 0.0627  max mem: 1011
# Epoch: [4]  [100/170]  eta: 0:00:19  lr: 0.000025  loss: 0.6947 (0.6762)  loss_classifier: 0.2803 (0.2421)  loss_box_reg: 0.3830 (0.4142)  loss_objectness: 0.0103 (0.0120)  loss_rpn_box_reg: 0.0049 (0.0079)  time: 0.2838  data: 0.0635  max mem: 1011
# Epoch: [4]  [120/170]  eta: 0:00:14  lr: 0.000025  loss: 0.5975 (0.6679)  loss_classifier: 0.2145 (0.2396)  loss_box_reg: 0.3433 (0.4084)  loss_objectness: 0.0089 (0.0120)  loss_rpn_box_reg: 0.0061 (0.0079)  time: 0.2889  data: 0.0622  max mem: 1011
# Epoch: [4]  [140/170]  eta: 0:00:08  lr: 0.000025  loss: 0.7045 (0.6739)  loss_classifier: 0.2225 (0.2397)  loss_box_reg: 0.4499 (0.4144)  loss_objectness: 0.0106 (0.0118)  loss_rpn_box_reg: 0.0041 (0.0079)  time: 0.2760  data: 0.0584  max mem: 1011
# Epoch: [4]  [160/170]  eta: 0:00:02  lr: 0.000025  loss: 0.6118 (0.6719)  loss_classifier: 0.2522 (0.2388)  loss_box_reg: 0.3779 (0.4132)  loss_objectness: 0.0083 (0.0116)  loss_rpn_box_reg: 0.0051 (0.0083)  time: 0.2851  data: 0.0655  max mem: 1011
# Epoch: [4]  [169/170]  eta: 0:00:00  lr: 0.000025  loss: 0.6421 (0.6706)  loss_classifier: 0.2468 (0.2379)  loss_box_reg: 0.4027 (0.4131)  loss_objectness: 0.0083 (0.0115)  loss_rpn_box_reg: 0.0051 (0.0081)  time: 0.2829  data: 0.0639  max mem: 1011
# Epoch: [4] Total time: 0:00:48 (0.2834 s / it)
# mAP:0.273
# 	AP at IoU level [0.50]: 0.516
# 	AP at IoU level [0.55]: 0.495
# 	AP at IoU level [0.60]: 0.473
# 	AP at IoU level [0.65]: 0.388
# 	AP at IoU level [0.70]: 0.326
# 	AP at IoU level [0.75]: 0.247
# 	AP at IoU level [0.80]: 0.200
# 	AP at IoU level [0.85]: 0.075
# 	AP at IoU level [0.90]: 0.013
# 	AP at IoU level [0.95]: 0.000
# Epoch: [5]  [  0/170]  eta: 0:00:59  lr: 0.000025  loss: 0.4993 (0.4993)  loss_classifier: 0.1831 (0.1831)  loss_box_reg: 0.3041 (0.3041)  loss_objectness: 0.0065 (0.0065)  loss_rpn_box_reg: 0.0056 (0.0056)  time: 0.3481  data: 0.0710  max mem: 1011
# Epoch: [5]  [ 20/170]  eta: 0:00:42  lr: 0.000025  loss: 0.6023 (0.6088)  loss_classifier: 0.2291 (0.2207)  loss_box_reg: 0.3772 (0.3722)  loss_objectness: 0.0076 (0.0103)  loss_rpn_box_reg: 0.0041 (0.0057)  time: 0.2799  data: 0.0641  max mem: 1011
# Epoch: [5]  [ 40/170]  eta: 0:00:35  lr: 0.000025  loss: 0.5763 (0.6137)  loss_classifier: 0.2065 (0.2186)  loss_box_reg: 0.3649 (0.3787)  loss_objectness: 0.0092 (0.0105)  loss_rpn_box_reg: 0.0048 (0.0059)  time: 0.2700  data: 0.0607  max mem: 1011
# Epoch: [5]  [ 60/170]  eta: 0:00:30  lr: 0.000025  loss: 0.7010 (0.6442)  loss_classifier: 0.2293 (0.2279)  loss_box_reg: 0.4546 (0.3988)  loss_objectness: 0.0109 (0.0109)  loss_rpn_box_reg: 0.0038 (0.0067)  time: 0.2729  data: 0.0600  max mem: 1011
# Epoch: [5]  [ 80/170]  eta: 0:00:24  lr: 0.000025  loss: 0.6438 (0.6393)  loss_classifier: 0.2076 (0.2268)  loss_box_reg: 0.3853 (0.3921)  loss_objectness: 0.0123 (0.0122)  loss_rpn_box_reg: 0.0067 (0.0082)  time: 0.2841  data: 0.0632  max mem: 1011
# Epoch: [5]  [100/170]  eta: 0:00:19  lr: 0.000025  loss: 0.6670 (0.6436)  loss_classifier: 0.2066 (0.2268)  loss_box_reg: 0.3980 (0.3944)  loss_objectness: 0.0076 (0.0132)  loss_rpn_box_reg: 0.0059 (0.0093)  time: 0.2822  data: 0.0642  max mem: 1011
# Epoch: [5]  [120/170]  eta: 0:00:13  lr: 0.000025  loss: 0.5976 (0.6358)  loss_classifier: 0.1949 (0.2212)  loss_box_reg: 0.3705 (0.3932)  loss_objectness: 0.0061 (0.0125)  loss_rpn_box_reg: 0.0031 (0.0088)  time: 0.2758  data: 0.0607  max mem: 1011
# Epoch: [5]  [140/170]  eta: 0:00:08  lr: 0.000025  loss: 0.6477 (0.6359)  loss_classifier: 0.2009 (0.2212)  loss_box_reg: 0.4000 (0.3943)  loss_objectness: 0.0055 (0.0120)  loss_rpn_box_reg: 0.0039 (0.0084)  time: 0.2798  data: 0.0629  max mem: 1011
# Epoch: [5]  [160/170]  eta: 0:00:02  lr: 0.000025  loss: 0.6418 (0.6369)  loss_classifier: 0.2341 (0.2207)  loss_box_reg: 0.3882 (0.3964)  loss_objectness: 0.0054 (0.0117)  loss_rpn_box_reg: 0.0029 (0.0082)  time: 0.2723  data: 0.0592  max mem: 1011
# Epoch: [5]  [169/170]  eta: 0:00:00  lr: 0.000025  loss: 0.5930 (0.6314)  loss_classifier: 0.2275 (0.2184)  loss_box_reg: 0.3784 (0.3939)  loss_objectness: 0.0045 (0.0113)  loss_rpn_box_reg: 0.0029 (0.0079)  time: 0.2692  data: 0.0596  max mem: 1011
# Epoch: [5] Total time: 0:00:47 (0.2772 s / it)
# mAP:0.262
# 	AP at IoU level [0.50]: 0.514
# 	AP at IoU level [0.55]: 0.485
# 	AP at IoU level [0.60]: 0.454
# 	AP at IoU level [0.65]: 0.361
# 	AP at IoU level [0.70]: 0.293
# 	AP at IoU level [0.75]: 0.238
# 	AP at IoU level [0.80]: 0.181
# 	AP at IoU level [0.85]: 0.067
# 	AP at IoU level [0.90]: 0.021
# 	AP at IoU level [0.95]: 0.000
# Epoch: [6]  [  0/170]  eta: 0:00:48  lr: 0.000013  loss: 0.4895 (0.4895)  loss_classifier: 0.2259 (0.2259)  loss_box_reg: 0.2601 (0.2601)  loss_objectness: 0.0022 (0.0022)  loss_rpn_box_reg: 0.0012 (0.0012)  time: 0.2852  data: 0.0848  max mem: 1011
# Epoch: [6]  [ 20/170]  eta: 0:00:41  lr: 0.000013  loss: 0.5413 (0.5816)  loss_classifier: 0.1950 (0.1852)  loss_box_reg: 0.3629 (0.3825)  loss_objectness: 0.0079 (0.0084)  loss_rpn_box_reg: 0.0034 (0.0055)  time: 0.2749  data: 0.0636  max mem: 1011
# Epoch: [6]  [ 40/170]  eta: 0:00:36  lr: 0.000013  loss: 0.5280 (0.5803)  loss_classifier: 0.1795 (0.1990)  loss_box_reg: 0.3187 (0.3640)  loss_objectness: 0.0104 (0.0096)  loss_rpn_box_reg: 0.0047 (0.0076)  time: 0.2851  data: 0.0639  max mem: 1011
# Epoch: [6]  [ 60/170]  eta: 0:00:30  lr: 0.000013  loss: 0.5336 (0.5724)  loss_classifier: 0.1990 (0.2022)  loss_box_reg: 0.3143 (0.3524)  loss_objectness: 0.0061 (0.0099)  loss_rpn_box_reg: 0.0025 (0.0080)  time: 0.2829  data: 0.0636  max mem: 1011
# Epoch: [6]  [ 80/170]  eta: 0:00:25  lr: 0.000013  loss: 0.5619 (0.5810)  loss_classifier: 0.1756 (0.2016)  loss_box_reg: 0.3774 (0.3617)  loss_objectness: 0.0055 (0.0100)  loss_rpn_box_reg: 0.0034 (0.0077)  time: 0.2742  data: 0.0627  max mem: 1011
# Epoch: [6]  [100/170]  eta: 0:00:19  lr: 0.000013  loss: 0.5394 (0.5733)  loss_classifier: 0.1771 (0.1954)  loss_box_reg: 0.3510 (0.3610)  loss_objectness: 0.0099 (0.0097)  loss_rpn_box_reg: 0.0042 (0.0072)  time: 0.2638  data: 0.0580  max mem: 1011
# Epoch: [6]  [120/170]  eta: 0:00:13  lr: 0.000013  loss: 0.5468 (0.5712)  loss_classifier: 0.2219 (0.1961)  loss_box_reg: 0.3376 (0.3585)  loss_objectness: 0.0075 (0.0097)  loss_rpn_box_reg: 0.0043 (0.0069)  time: 0.2714  data: 0.0612  max mem: 1011
# Epoch: [6]  [140/170]  eta: 0:00:08  lr: 0.000013  loss: 0.5985 (0.5762)  loss_classifier: 0.2188 (0.2000)  loss_box_reg: 0.3644 (0.3591)  loss_objectness: 0.0090 (0.0101)  loss_rpn_box_reg: 0.0071 (0.0071)  time: 0.2829  data: 0.0600  max mem: 1011
# Epoch: [6]  [160/170]  eta: 0:00:02  lr: 0.000013  loss: 0.5785 (0.5793)  loss_classifier: 0.1833 (0.2020)  loss_box_reg: 0.3583 (0.3599)  loss_objectness: 0.0052 (0.0101)  loss_rpn_box_reg: 0.0041 (0.0073)  time: 0.2747  data: 0.0609  max mem: 1011
# Epoch: [6]  [169/170]  eta: 0:00:00  lr: 0.000013  loss: 0.6044 (0.5825)  loss_classifier: 0.1890 (0.2027)  loss_box_reg: 0.3882 (0.3621)  loss_objectness: 0.0082 (0.0102)  loss_rpn_box_reg: 0.0055 (0.0074)  time: 0.2791  data: 0.0623  max mem: 1011
# Epoch: [6] Total time: 0:00:46 (0.2764 s / it)
# mAP:0.269
# 	AP at IoU level [0.50]: 0.513
# 	AP at IoU level [0.55]: 0.505
# 	AP at IoU level [0.60]: 0.457
# 	AP at IoU level [0.65]: 0.371
# 	AP at IoU level [0.70]: 0.310
# 	AP at IoU level [0.75]: 0.257
# 	AP at IoU level [0.80]: 0.201
# 	AP at IoU level [0.85]: 0.062
# 	AP at IoU level [0.90]: 0.019
# 	AP at IoU level [0.95]: 0.000
# Epoch: [7]  [  0/170]  eta: 0:00:53  lr: 0.000013  loss: 0.5239 (0.5239)  loss_classifier: 0.1878 (0.1878)  loss_box_reg: 0.3330 (0.3330)  loss_objectness: 0.0022 (0.0022)  loss_rpn_box_reg: 0.0010 (0.0010)  time: 0.3137  data: 0.0599  max mem: 1011
# Epoch: [7]  [ 20/170]  eta: 0:00:42  lr: 0.000013  loss: 0.6015 (0.6025)  loss_classifier: 0.2236 (0.2303)  loss_box_reg: 0.3451 (0.3548)  loss_objectness: 0.0052 (0.0094)  loss_rpn_box_reg: 0.0030 (0.0080)  time: 0.2810  data: 0.0587  max mem: 1011
# Epoch: [7]  [ 40/170]  eta: 0:00:36  lr: 0.000013  loss: 0.5726 (0.5902)  loss_classifier: 0.1996 (0.2120)  loss_box_reg: 0.3370 (0.3615)  loss_objectness: 0.0054 (0.0097)  loss_rpn_box_reg: 0.0042 (0.0070)  time: 0.2718  data: 0.0626  max mem: 1011
# Epoch: [7]  [ 60/170]  eta: 0:00:30  lr: 0.000013  loss: 0.5821 (0.5853)  loss_classifier: 0.2142 (0.2136)  loss_box_reg: 0.3424 (0.3538)  loss_objectness: 0.0038 (0.0097)  loss_rpn_box_reg: 0.0064 (0.0082)  time: 0.2738  data: 0.0619  max mem: 1011
# Epoch: [7]  [ 80/170]  eta: 0:00:24  lr: 0.000013  loss: 0.5088 (0.5781)  loss_classifier: 0.1720 (0.2039)  loss_box_reg: 0.3270 (0.3582)  loss_objectness: 0.0066 (0.0089)  loss_rpn_box_reg: 0.0038 (0.0072)  time: 0.2679  data: 0.0581  max mem: 1011
# Epoch: [7]  [100/170]  eta: 0:00:19  lr: 0.000013  loss: 0.5579 (0.5780)  loss_classifier: 0.1718 (0.2029)  loss_box_reg: 0.3437 (0.3576)  loss_objectness: 0.0072 (0.0097)  loss_rpn_box_reg: 0.0054 (0.0077)  time: 0.2831  data: 0.0630  max mem: 1011
# Epoch: [7]  [120/170]  eta: 0:00:13  lr: 0.000013  loss: 0.5146 (0.5674)  loss_classifier: 0.1683 (0.1983)  loss_box_reg: 0.3229 (0.3520)  loss_objectness: 0.0073 (0.0097)  loss_rpn_box_reg: 0.0039 (0.0073)  time: 0.2766  data: 0.0600  max mem: 1011
# Epoch: [7]  [140/170]  eta: 0:00:08  lr: 0.000013  loss: 0.5809 (0.5691)  loss_classifier: 0.1657 (0.1974)  loss_box_reg: 0.3544 (0.3548)  loss_objectness: 0.0087 (0.0098)  loss_rpn_box_reg: 0.0044 (0.0071)  time: 0.2675  data: 0.0635  max mem: 1011
# Epoch: [7]  [160/170]  eta: 0:00:02  lr: 0.000013  loss: 0.4753 (0.5623)  loss_classifier: 0.1726 (0.1952)  loss_box_reg: 0.3238 (0.3503)  loss_objectness: 0.0075 (0.0098)  loss_rpn_box_reg: 0.0043 (0.0071)  time: 0.2666  data: 0.0610  max mem: 1011
# Epoch: [7]  [169/170]  eta: 0:00:00  lr: 0.000013  loss: 0.4600 (0.5584)  loss_classifier: 0.1815 (0.1945)  loss_box_reg: 0.2862 (0.3469)  loss_objectness: 0.0096 (0.0098)  loss_rpn_box_reg: 0.0053 (0.0072)  time: 0.2726  data: 0.0592  max mem: 1011
# Epoch: [7] Total time: 0:00:46 (0.2741 s / it)
# mAP:0.268
# 	AP at IoU level [0.50]: 0.511
# 	AP at IoU level [0.55]: 0.490
# 	AP at IoU level [0.60]: 0.452
# 	AP at IoU level [0.65]: 0.373
# 	AP at IoU level [0.70]: 0.314
# 	AP at IoU level [0.75]: 0.280
# 	AP at IoU level [0.80]: 0.176
# 	AP at IoU level [0.85]: 0.076
# 	AP at IoU level [0.90]: 0.012
# 	AP at IoU level [0.95]: 0.000
# Epoch: [8]  [  0/170]  eta: 0:00:47  lr: 0.000006  loss: 0.6270 (0.6270)  loss_classifier: 0.1822 (0.1822)  loss_box_reg: 0.4300 (0.4300)  loss_objectness: 0.0109 (0.0109)  loss_rpn_box_reg: 0.0039 (0.0039)  time: 0.2776  data: 0.0687  max mem: 1011
# Epoch: [8]  [ 20/170]  eta: 0:00:40  lr: 0.000006  loss: 0.4978 (0.5330)  loss_classifier: 0.1757 (0.1811)  loss_box_reg: 0.3061 (0.3383)  loss_objectness: 0.0049 (0.0082)  loss_rpn_box_reg: 0.0032 (0.0055)  time: 0.2694  data: 0.0592  max mem: 1011
# Epoch: [8]  [ 40/170]  eta: 0:00:35  lr: 0.000006  loss: 0.5104 (0.5248)  loss_classifier: 0.1517 (0.1814)  loss_box_reg: 0.2983 (0.3308)  loss_objectness: 0.0038 (0.0076)  loss_rpn_box_reg: 0.0026 (0.0050)  time: 0.2749  data: 0.0631  max mem: 1011
# Epoch: [8]  [ 60/170]  eta: 0:00:29  lr: 0.000006  loss: 0.4990 (0.5092)  loss_classifier: 0.1485 (0.1743)  loss_box_reg: 0.3281 (0.3223)  loss_objectness: 0.0064 (0.0075)  loss_rpn_box_reg: 0.0028 (0.0051)  time: 0.2704  data: 0.0612  max mem: 1011
# Epoch: [8]  [ 80/170]  eta: 0:00:24  lr: 0.000006  loss: 0.5204 (0.5186)  loss_classifier: 0.1773 (0.1772)  loss_box_reg: 0.3433 (0.3285)  loss_objectness: 0.0074 (0.0078)  loss_rpn_box_reg: 0.0034 (0.0051)  time: 0.2728  data: 0.0651  max mem: 1011
# Epoch: [8]  [100/170]  eta: 0:00:19  lr: 0.000006  loss: 0.4859 (0.5190)  loss_classifier: 0.1634 (0.1788)  loss_box_reg: 0.2830 (0.3257)  loss_objectness: 0.0084 (0.0086)  loss_rpn_box_reg: 0.0044 (0.0059)  time: 0.2743  data: 0.0639  max mem: 1011
# Epoch: [8]  [120/170]  eta: 0:00:13  lr: 0.000006  loss: 0.4234 (0.5089)  loss_classifier: 0.1663 (0.1752)  loss_box_reg: 0.2655 (0.3187)  loss_objectness: 0.0072 (0.0090)  loss_rpn_box_reg: 0.0039 (0.0060)  time: 0.2712  data: 0.0613  max mem: 1011
# Epoch: [8]  [140/170]  eta: 0:00:08  lr: 0.000006  loss: 0.4969 (0.5103)  loss_classifier: 0.1823 (0.1787)  loss_box_reg: 0.2807 (0.3148)  loss_objectness: 0.0085 (0.0099)  loss_rpn_box_reg: 0.0067 (0.0069)  time: 0.2746  data: 0.0627  max mem: 1011
# Epoch: [8]  [160/170]  eta: 0:00:02  lr: 0.000006  loss: 0.5277 (0.5161)  loss_classifier: 0.1782 (0.1803)  loss_box_reg: 0.3308 (0.3185)  loss_objectness: 0.0097 (0.0102)  loss_rpn_box_reg: 0.0055 (0.0071)  time: 0.2736  data: 0.0618  max mem: 1011
# Epoch: [8]  [169/170]  eta: 0:00:00  lr: 0.000006  loss: 0.5532 (0.5221)  loss_classifier: 0.1652 (0.1826)  loss_box_reg: 0.3678 (0.3223)  loss_objectness: 0.0072 (0.0102)  loss_rpn_box_reg: 0.0038 (0.0071)  time: 0.2721  data: 0.0612  max mem: 1011
# Epoch: [8] Total time: 0:00:46 (0.2729 s / it)
# mAP:0.274
# 	AP at IoU level [0.50]: 0.516
# 	AP at IoU level [0.55]: 0.495
# 	AP at IoU level [0.60]: 0.460
# 	AP at IoU level [0.65]: 0.395
# 	AP at IoU level [0.70]: 0.307
# 	AP at IoU level [0.75]: 0.267
# 	AP at IoU level [0.80]: 0.189
# 	AP at IoU level [0.85]: 0.081
# 	AP at IoU level [0.90]: 0.026
# 	AP at IoU level [0.95]: 0.000
# Epoch: [9]  [  0/170]  eta: 0:00:45  lr: 0.000006  loss: 0.5406 (0.5406)  loss_classifier: 0.1994 (0.1994)  loss_box_reg: 0.3233 (0.3233)  loss_objectness: 0.0123 (0.0123)  loss_rpn_box_reg: 0.0055 (0.0055)  time: 0.2683  data: 0.0800  max mem: 1011
# Epoch: [9]  [ 20/170]  eta: 0:00:40  lr: 0.000006  loss: 0.5094 (0.5090)  loss_classifier: 0.1776 (0.1728)  loss_box_reg: 0.3328 (0.3259)  loss_objectness: 0.0065 (0.0065)  loss_rpn_box_reg: 0.0041 (0.0038)  time: 0.2714  data: 0.0623  max mem: 1011
# Epoch: [9]  [ 40/170]  eta: 0:00:35  lr: 0.000006  loss: 0.5860 (0.5359)  loss_classifier: 0.1966 (0.1782)  loss_box_reg: 0.3727 (0.3426)  loss_objectness: 0.0107 (0.0093)  loss_rpn_box_reg: 0.0038 (0.0058)  time: 0.2759  data: 0.0648  max mem: 1011
# Epoch: [9]  [ 60/170]  eta: 0:00:29  lr: 0.000006  loss: 0.4879 (0.5233)  loss_classifier: 0.1836 (0.1755)  loss_box_reg: 0.3005 (0.3330)  loss_objectness: 0.0065 (0.0091)  loss_rpn_box_reg: 0.0034 (0.0056)  time: 0.2708  data: 0.0617  max mem: 1011
# Epoch: [9]  [ 80/170]  eta: 0:00:24  lr: 0.000006  loss: 0.4027 (0.4993)  loss_classifier: 0.1540 (0.1702)  loss_box_reg: 0.2351 (0.3152)  loss_objectness: 0.0032 (0.0086)  loss_rpn_box_reg: 0.0015 (0.0053)  time: 0.2638  data: 0.0569  max mem: 1011
# Epoch: [9]  [100/170]  eta: 0:00:18  lr: 0.000006  loss: 0.5093 (0.5066)  loss_classifier: 0.1895 (0.1742)  loss_box_reg: 0.3196 (0.3184)  loss_objectness: 0.0078 (0.0086)  loss_rpn_box_reg: 0.0051 (0.0055)  time: 0.2752  data: 0.0628  max mem: 1011
# Epoch: [9]  [120/170]  eta: 0:00:13  lr: 0.000006  loss: 0.4616 (0.4960)  loss_classifier: 0.1660 (0.1711)  loss_box_reg: 0.2667 (0.3113)  loss_objectness: 0.0050 (0.0083)  loss_rpn_box_reg: 0.0035 (0.0052)  time: 0.2672  data: 0.0614  max mem: 1011
# Epoch: [9]  [140/170]  eta: 0:00:08  lr: 0.000006  loss: 0.5464 (0.5063)  loss_classifier: 0.1691 (0.1759)  loss_box_reg: 0.3253 (0.3143)  loss_objectness: 0.0111 (0.0096)  loss_rpn_box_reg: 0.0040 (0.0066)  time: 0.2758  data: 0.0631  max mem: 1011
# Epoch: [9]  [160/170]  eta: 0:00:02  lr: 0.000006  loss: 0.4885 (0.5070)  loss_classifier: 0.1775 (0.1767)  loss_box_reg: 0.2938 (0.3134)  loss_objectness: 0.0084 (0.0100)  loss_rpn_box_reg: 0.0063 (0.0070)  time: 0.2742  data: 0.0615  max mem: 1011
# Epoch: [9]  [169/170]  eta: 0:00:00  lr: 0.000006  loss: 0.4885 (0.5046)  loss_classifier: 0.1752 (0.1765)  loss_box_reg: 0.3110 (0.3111)  loss_objectness: 0.0100 (0.0100)  loss_rpn_box_reg: 0.0063 (0.0070)  time: 0.2778  data: 0.0641  max mem: 1011
# Epoch: [9] Total time: 0:00:46 (0.2724 s / it)
# mAP:0.270
# 	AP at IoU level [0.50]: 0.517
# 	AP at IoU level [0.55]: 0.493
# 	AP at IoU level [0.60]: 0.451
# 	AP at IoU level [0.65]: 0.380
# 	AP at IoU level [0.70]: 0.305
# 	AP at IoU level [0.75]: 0.260
# 	AP at IoU level [0.80]: 0.181
# 	AP at IoU level [0.85]: 0.088
# 	AP at IoU level [0.90]: 0.027
# 	AP at IoU level [0.95]: 0.000
# Epoch: [10]  [  0/170]  eta: 0:00:49  lr: 0.000003  loss: 0.3297 (0.3297)  loss_classifier: 0.0923 (0.0923)  loss_box_reg: 0.2346 (0.2346)  loss_objectness: 0.0021 (0.0021)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 0.2910  data: 0.0551  max mem: 1011
# Epoch: [10]  [ 20/170]  eta: 0:00:41  lr: 0.000003  loss: 0.4982 (0.5182)  loss_classifier: 0.1976 (0.1960)  loss_box_reg: 0.2859 (0.2981)  loss_objectness: 0.0077 (0.0136)  loss_rpn_box_reg: 0.0030 (0.0104)  time: 0.2775  data: 0.0632  max mem: 1011
# Epoch: [10]  [ 40/170]  eta: 0:00:35  lr: 0.000003  loss: 0.3925 (0.4932)  loss_classifier: 0.1519 (0.1796)  loss_box_reg: 0.2702 (0.2924)  loss_objectness: 0.0039 (0.0119)  loss_rpn_box_reg: 0.0026 (0.0092)  time: 0.2711  data: 0.0609  max mem: 1011
# Epoch: [10]  [ 60/170]  eta: 0:00:30  lr: 0.000003  loss: 0.4681 (0.4931)  loss_classifier: 0.1699 (0.1768)  loss_box_reg: 0.2842 (0.2978)  loss_objectness: 0.0058 (0.0107)  loss_rpn_box_reg: 0.0033 (0.0079)  time: 0.2713  data: 0.0602  max mem: 1011
# Epoch: [10]  [ 80/170]  eta: 0:00:24  lr: 0.000003  loss: 0.4616 (0.4899)  loss_classifier: 0.1465 (0.1747)  loss_box_reg: 0.2833 (0.2977)  loss_objectness: 0.0079 (0.0101)  loss_rpn_box_reg: 0.0040 (0.0075)  time: 0.2659  data: 0.0623  max mem: 1011
# Epoch: [10]  [100/170]  eta: 0:00:18  lr: 0.000003  loss: 0.4913 (0.4911)  loss_classifier: 0.1613 (0.1743)  loss_box_reg: 0.3145 (0.2991)  loss_objectness: 0.0086 (0.0104)  loss_rpn_box_reg: 0.0036 (0.0073)  time: 0.2677  data: 0.0620  max mem: 1011
# Epoch: [10]  [120/170]  eta: 0:00:13  lr: 0.000003  loss: 0.4226 (0.4867)  loss_classifier: 0.1338 (0.1721)  loss_box_reg: 0.2707 (0.2976)  loss_objectness: 0.0069 (0.0100)  loss_rpn_box_reg: 0.0035 (0.0070)  time: 0.2595  data: 0.0585  max mem: 1011
# Epoch: [10]  [140/170]  eta: 0:00:08  lr: 0.000003  loss: 0.4784 (0.4885)  loss_classifier: 0.1770 (0.1733)  loss_box_reg: 0.3118 (0.2988)  loss_objectness: 0.0059 (0.0097)  loss_rpn_box_reg: 0.0041 (0.0067)  time: 0.2742  data: 0.0639  max mem: 1011
# Epoch: [10]  [160/170]  eta: 0:00:02  lr: 0.000003  loss: 0.4924 (0.4941)  loss_classifier: 0.1792 (0.1746)  loss_box_reg: 0.2961 (0.3030)  loss_objectness: 0.0086 (0.0099)  loss_rpn_box_reg: 0.0058 (0.0067)  time: 0.2680  data: 0.0593  max mem: 1011
# Epoch: [10]  [169/170]  eta: 0:00:00  lr: 0.000003  loss: 0.5024 (0.4951)  loss_classifier: 0.1902 (0.1750)  loss_box_reg: 0.2989 (0.3032)  loss_objectness: 0.0123 (0.0100)  loss_rpn_box_reg: 0.0067 (0.0068)  time: 0.2707  data: 0.0578  max mem: 1011
# Epoch: [10] Total time: 0:00:45 (0.2697 s / it)
# mAP:0.272
# 	AP at IoU level [0.50]: 0.519
# 	AP at IoU level [0.55]: 0.503
# 	AP at IoU level [0.60]: 0.457
# 	AP at IoU level [0.65]: 0.382
# 	AP at IoU level [0.70]: 0.317
# 	AP at IoU level [0.75]: 0.258
# 	AP at IoU level [0.80]: 0.156
# 	AP at IoU level [0.85]: 0.088
# 	AP at IoU level [0.90]: 0.036
# 	AP at IoU level [0.95]: 0.000
# Epoch: [11]  [  0/170]  eta: 0:00:54  lr: 0.000003  loss: 0.6202 (0.6202)  loss_classifier: 0.2377 (0.2377)  loss_box_reg: 0.3469 (0.3469)  loss_objectness: 0.0238 (0.0238)  loss_rpn_box_reg: 0.0117 (0.0117)  time: 0.3231  data: 0.0821  max mem: 1011
# Epoch: [11]  [ 20/170]  eta: 0:00:40  lr: 0.000003  loss: 0.4555 (0.4586)  loss_classifier: 0.1414 (0.1627)  loss_box_reg: 0.2792 (0.2833)  loss_objectness: 0.0053 (0.0083)  loss_rpn_box_reg: 0.0035 (0.0044)  time: 0.2682  data: 0.0622  max mem: 1011
# Epoch: [11]  [ 40/170]  eta: 0:00:35  lr: 0.000003  loss: 0.4539 (0.4670)  loss_classifier: 0.1439 (0.1608)  loss_box_reg: 0.2757 (0.2943)  loss_objectness: 0.0046 (0.0076)  loss_rpn_box_reg: 0.0026 (0.0042)  time: 0.2754  data: 0.0581  max mem: 1011
# Epoch: [11]  [ 60/170]  eta: 0:00:29  lr: 0.000003  loss: 0.3902 (0.4523)  loss_classifier: 0.1538 (0.1562)  loss_box_reg: 0.2610 (0.2832)  loss_objectness: 0.0047 (0.0082)  loss_rpn_box_reg: 0.0032 (0.0047)  time: 0.2668  data: 0.0590  max mem: 1011
# Epoch: [11]  [ 80/170]  eta: 0:00:24  lr: 0.000003  loss: 0.5329 (0.4719)  loss_classifier: 0.1802 (0.1671)  loss_box_reg: 0.3270 (0.2904)  loss_objectness: 0.0065 (0.0089)  loss_rpn_box_reg: 0.0035 (0.0055)  time: 0.2746  data: 0.0623  max mem: 1011
# Epoch: [11]  [100/170]  eta: 0:00:19  lr: 0.000003  loss: 0.5218 (0.4827)  loss_classifier: 0.1674 (0.1707)  loss_box_reg: 0.3060 (0.2963)  loss_objectness: 0.0085 (0.0098)  loss_rpn_box_reg: 0.0054 (0.0060)  time: 0.2710  data: 0.0613  max mem: 1011
# Epoch: [11]  [120/170]  eta: 0:00:13  lr: 0.000003  loss: 0.5760 (0.4983)  loss_classifier: 0.1918 (0.1765)  loss_box_reg: 0.3630 (0.3045)  loss_objectness: 0.0097 (0.0103)  loss_rpn_box_reg: 0.0050 (0.0070)  time: 0.2771  data: 0.0587  max mem: 1011
# Epoch: [11]  [140/170]  eta: 0:00:08  lr: 0.000003  loss: 0.3678 (0.4885)  loss_classifier: 0.1071 (0.1713)  loss_box_reg: 0.2502 (0.3007)  loss_objectness: 0.0060 (0.0098)  loss_rpn_box_reg: 0.0035 (0.0067)  time: 0.2704  data: 0.0618  max mem: 1011
# Epoch: [11]  [160/170]  eta: 0:00:02  lr: 0.000003  loss: 0.5034 (0.4860)  loss_classifier: 0.1535 (0.1680)  loss_box_reg: 0.2860 (0.3015)  loss_objectness: 0.0049 (0.0097)  loss_rpn_box_reg: 0.0037 (0.0066)  time: 0.2725  data: 0.0603  max mem: 1011
# Epoch: [11]  [169/170]  eta: 0:00:00  lr: 0.000003  loss: 0.4863 (0.4865)  loss_classifier: 0.1489 (0.1686)  loss_box_reg: 0.2740 (0.3014)  loss_objectness: 0.0078 (0.0098)  loss_rpn_box_reg: 0.0039 (0.0067)  time: 0.2728  data: 0.0597  max mem: 1011
# Epoch: [11] Total time: 0:00:46 (0.2726 s / it)
# mAP:0.269
# 	AP at IoU level [0.50]: 0.518
# 	AP at IoU level [0.55]: 0.476
# 	AP at IoU level [0.60]: 0.442
# 	AP at IoU level [0.65]: 0.387
# 	AP at IoU level [0.70]: 0.311
# 	AP at IoU level [0.75]: 0.261
# 	AP at IoU level [0.80]: 0.183
# 	AP at IoU level [0.85]: 0.090
# 	AP at IoU level [0.90]: 0.018
# 	AP at IoU level [0.95]: 0.000
# Epoch: [12]  [  0/170]  eta: 0:00:48  lr: 0.000002  loss: 0.5131 (0.5131)  loss_classifier: 0.2119 (0.2119)  loss_box_reg: 0.2682 (0.2682)  loss_objectness: 0.0221 (0.0221)  loss_rpn_box_reg: 0.0110 (0.0110)  time: 0.2856  data: 0.0847  max mem: 1011
# Epoch: [12]  [ 20/170]  eta: 0:00:39  lr: 0.000002  loss: 0.5058 (0.4936)  loss_classifier: 0.1511 (0.1746)  loss_box_reg: 0.3075 (0.3025)  loss_objectness: 0.0073 (0.0105)  loss_rpn_box_reg: 0.0045 (0.0060)  time: 0.2611  data: 0.0589  max mem: 1011
# Epoch: [12]  [ 40/170]  eta: 0:00:34  lr: 0.000002  loss: 0.4762 (0.4935)  loss_classifier: 0.1600 (0.1764)  loss_box_reg: 0.2985 (0.2997)  loss_objectness: 0.0059 (0.0101)  loss_rpn_box_reg: 0.0028 (0.0072)  time: 0.2673  data: 0.0594  max mem: 1011
# Epoch: [12]  [ 60/170]  eta: 0:00:29  lr: 0.000002  loss: 0.4076 (0.4715)  loss_classifier: 0.1458 (0.1690)  loss_box_reg: 0.2479 (0.2860)  loss_objectness: 0.0067 (0.0096)  loss_rpn_box_reg: 0.0039 (0.0069)  time: 0.2697  data: 0.0622  max mem: 1011
# Epoch: [12]  [ 80/170]  eta: 0:00:24  lr: 0.000002  loss: 0.5495 (0.4912)  loss_classifier: 0.1876 (0.1785)  loss_box_reg: 0.3089 (0.2946)  loss_objectness: 0.0112 (0.0104)  loss_rpn_box_reg: 0.0068 (0.0077)  time: 0.2782  data: 0.0632  max mem: 1011
# Epoch: [12]  [100/170]  eta: 0:00:18  lr: 0.000002  loss: 0.4132 (0.4828)  loss_classifier: 0.1493 (0.1779)  loss_box_reg: 0.2609 (0.2869)  loss_objectness: 0.0063 (0.0104)  loss_rpn_box_reg: 0.0047 (0.0077)  time: 0.2731  data: 0.0601  max mem: 1011
# Epoch: [12]  [120/170]  eta: 0:00:13  lr: 0.000002  loss: 0.4238 (0.4793)  loss_classifier: 0.1427 (0.1720)  loss_box_reg: 0.2820 (0.2903)  loss_objectness: 0.0056 (0.0099)  loss_rpn_box_reg: 0.0031 (0.0071)  time: 0.2654  data: 0.0625  max mem: 1011
# Epoch: [12]  [140/170]  eta: 0:00:08  lr: 0.000002  loss: 0.4580 (0.4775)  loss_classifier: 0.1505 (0.1705)  loss_box_reg: 0.2889 (0.2906)  loss_objectness: 0.0077 (0.0097)  loss_rpn_box_reg: 0.0048 (0.0068)  time: 0.2723  data: 0.0618  max mem: 1011
# Epoch: [12]  [160/170]  eta: 0:00:02  lr: 0.000002  loss: 0.4594 (0.4750)  loss_classifier: 0.1549 (0.1699)  loss_box_reg: 0.2455 (0.2886)  loss_objectness: 0.0068 (0.0097)  loss_rpn_box_reg: 0.0055 (0.0068)  time: 0.2733  data: 0.0607  max mem: 1011
# Epoch: [12]  [169/170]  eta: 0:00:00  lr: 0.000002  loss: 0.4728 (0.4763)  loss_classifier: 0.1637 (0.1702)  loss_box_reg: 0.3012 (0.2896)  loss_objectness: 0.0067 (0.0098)  loss_rpn_box_reg: 0.0044 (0.0067)  time: 0.2725  data: 0.0601  max mem: 1011
# Epoch: [12] Total time: 0:00:46 (0.2707 s / it)
# mAP:0.279
# 	AP at IoU level [0.50]: 0.518
# 	AP at IoU level [0.55]: 0.500
# 	AP at IoU level [0.60]: 0.477
# 	AP at IoU level [0.65]: 0.408
# 	AP at IoU level [0.70]: 0.321
# 	AP at IoU level [0.75]: 0.259
# 	AP at IoU level [0.80]: 0.183
# 	AP at IoU level [0.85]: 0.100
# 	AP at IoU level [0.90]: 0.022
# 	AP at IoU level [0.95]: 0.000
# Epoch: [13]  [  0/170]  eta: 0:00:48  lr: 0.000002  loss: 0.5302 (0.5302)  loss_classifier: 0.1985 (0.1985)  loss_box_reg: 0.3061 (0.3061)  loss_objectness: 0.0180 (0.0180)  loss_rpn_box_reg: 0.0076 (0.0076)  time: 0.2848  data: 0.0706  max mem: 1011
# Epoch: [13]  [ 20/170]  eta: 0:00:41  lr: 0.000002  loss: 0.4043 (0.4343)  loss_classifier: 0.1350 (0.1527)  loss_box_reg: 0.2443 (0.2690)  loss_objectness: 0.0052 (0.0075)  loss_rpn_box_reg: 0.0023 (0.0051)  time: 0.2775  data: 0.0625  max mem: 1011
# Epoch: [13]  [ 40/170]  eta: 0:00:35  lr: 0.000002  loss: 0.4099 (0.4475)  loss_classifier: 0.1579 (0.1574)  loss_box_reg: 0.2605 (0.2780)  loss_objectness: 0.0035 (0.0071)  loss_rpn_box_reg: 0.0038 (0.0050)  time: 0.2664  data: 0.0570  max mem: 1011
# Epoch: [13]  [ 60/170]  eta: 0:00:29  lr: 0.000002  loss: 0.4781 (0.4562)  loss_classifier: 0.1668 (0.1627)  loss_box_reg: 0.3023 (0.2780)  loss_objectness: 0.0103 (0.0092)  loss_rpn_box_reg: 0.0062 (0.0062)  time: 0.2647  data: 0.0593  max mem: 1011
# Epoch: [13]  [ 80/170]  eta: 0:00:24  lr: 0.000002  loss: 0.5392 (0.4698)  loss_classifier: 0.1690 (0.1656)  loss_box_reg: 0.3503 (0.2876)  loss_objectness: 0.0087 (0.0100)  loss_rpn_box_reg: 0.0034 (0.0066)  time: 0.2649  data: 0.0591  max mem: 1011
# Epoch: [13]  [100/170]  eta: 0:00:18  lr: 0.000002  loss: 0.4228 (0.4704)  loss_classifier: 0.1506 (0.1663)  loss_box_reg: 0.2723 (0.2873)  loss_objectness: 0.0045 (0.0099)  loss_rpn_box_reg: 0.0028 (0.0069)  time: 0.2721  data: 0.0617  max mem: 1011
# Epoch: [13]  [120/170]  eta: 0:00:13  lr: 0.000002  loss: 0.5484 (0.4791)  loss_classifier: 0.1710 (0.1696)  loss_box_reg: 0.3301 (0.2923)  loss_objectness: 0.0061 (0.0100)  loss_rpn_box_reg: 0.0046 (0.0072)  time: 0.2779  data: 0.0637  max mem: 1011
# Epoch: [13]  [140/170]  eta: 0:00:08  lr: 0.000002  loss: 0.3230 (0.4697)  loss_classifier: 0.1252 (0.1657)  loss_box_reg: 0.2435 (0.2878)  loss_objectness: 0.0068 (0.0094)  loss_rpn_box_reg: 0.0029 (0.0067)  time: 0.2689  data: 0.0602  max mem: 1011
# Epoch: [13]  [160/170]  eta: 0:00:02  lr: 0.000002  loss: 0.4765 (0.4724)  loss_classifier: 0.1736 (0.1675)  loss_box_reg: 0.2823 (0.2886)  loss_objectness: 0.0085 (0.0096)  loss_rpn_box_reg: 0.0031 (0.0067)  time: 0.2736  data: 0.0598  max mem: 1011
# Epoch: [13]  [169/170]  eta: 0:00:00  lr: 0.000002  loss: 0.4765 (0.4724)  loss_classifier: 0.1601 (0.1671)  loss_box_reg: 0.3112 (0.2893)  loss_objectness: 0.0089 (0.0095)  loss_rpn_box_reg: 0.0039 (0.0066)  time: 0.2739  data: 0.0599  max mem: 1011
# Epoch: [13] Total time: 0:00:46 (0.2711 s / it)
# mAP:0.270
# 	AP at IoU level [0.50]: 0.513
# 	AP at IoU level [0.55]: 0.501
# 	AP at IoU level [0.60]: 0.464
# 	AP at IoU level [0.65]: 0.376
# 	AP at IoU level [0.70]: 0.313
# 	AP at IoU level [0.75]: 0.249
# 	AP at IoU level [0.80]: 0.178
# 	AP at IoU level [0.85]: 0.087
# 	AP at IoU level [0.90]: 0.017
# 	AP at IoU level [0.95]: 0.000
# Epoch: [14]  [  0/170]  eta: 0:00:48  lr: 0.000001  loss: 0.3274 (0.3274)  loss_classifier: 0.1099 (0.1099)  loss_box_reg: 0.2132 (0.2132)  loss_objectness: 0.0038 (0.0038)  loss_rpn_box_reg: 0.0005 (0.0005)  time: 0.2865  data: 0.0666  max mem: 1011
# Epoch: [14]  [ 20/170]  eta: 0:00:40  lr: 0.000001  loss: 0.4347 (0.4438)  loss_classifier: 0.1507 (0.1546)  loss_box_reg: 0.2541 (0.2761)  loss_objectness: 0.0047 (0.0083)  loss_rpn_box_reg: 0.0037 (0.0049)  time: 0.2672  data: 0.0560  max mem: 1011
# Epoch: [14]  [ 40/170]  eta: 0:00:35  lr: 0.000001  loss: 0.4190 (0.4407)  loss_classifier: 0.1599 (0.1542)  loss_box_reg: 0.2816 (0.2727)  loss_objectness: 0.0064 (0.0085)  loss_rpn_box_reg: 0.0038 (0.0052)  time: 0.2717  data: 0.0634  max mem: 1011
# Epoch: [14]  [ 60/170]  eta: 0:00:29  lr: 0.000001  loss: 0.4407 (0.4436)  loss_classifier: 0.1483 (0.1564)  loss_box_reg: 0.2698 (0.2730)  loss_objectness: 0.0046 (0.0083)  loss_rpn_box_reg: 0.0027 (0.0058)  time: 0.2689  data: 0.0607  max mem: 1011
# Epoch: [14]  [ 80/170]  eta: 0:00:24  lr: 0.000001  loss: 0.4263 (0.4477)  loss_classifier: 0.1434 (0.1587)  loss_box_reg: 0.2689 (0.2739)  loss_objectness: 0.0084 (0.0088)  loss_rpn_box_reg: 0.0050 (0.0063)  time: 0.2638  data: 0.0595  max mem: 1011
# Epoch: [14]  [100/170]  eta: 0:00:18  lr: 0.000001  loss: 0.5081 (0.4630)  loss_classifier: 0.1793 (0.1667)  loss_box_reg: 0.3081 (0.2802)  loss_objectness: 0.0093 (0.0093)  loss_rpn_box_reg: 0.0067 (0.0067)  time: 0.2776  data: 0.0643  max mem: 1011
# Epoch: [14]  [120/170]  eta: 0:00:13  lr: 0.000001  loss: 0.4259 (0.4665)  loss_classifier: 0.1483 (0.1676)  loss_box_reg: 0.2739 (0.2823)  loss_objectness: 0.0071 (0.0096)  loss_rpn_box_reg: 0.0054 (0.0070)  time: 0.2844  data: 0.0674  max mem: 1011
# Epoch: [14]  [140/170]  eta: 0:00:08  lr: 0.000001  loss: 0.4193 (0.4658)  loss_classifier: 0.1347 (0.1671)  loss_box_reg: 0.2675 (0.2824)  loss_objectness: 0.0066 (0.0095)  loss_rpn_box_reg: 0.0036 (0.0068)  time: 0.2760  data: 0.0642  max mem: 1011
# Epoch: [14]  [160/170]  eta: 0:00:02  lr: 0.000001  loss: 0.4646 (0.4649)  loss_classifier: 0.1718 (0.1673)  loss_box_reg: 0.2675 (0.2817)  loss_objectness: 0.0057 (0.0094)  loss_rpn_box_reg: 0.0038 (0.0065)  time: 0.2738  data: 0.0653  max mem: 1011
# Epoch: [14]  [169/170]  eta: 0:00:00  lr: 0.000001  loss: 0.4646 (0.4682)  loss_classifier: 0.1717 (0.1687)  loss_box_reg: 0.2752 (0.2834)  loss_objectness: 0.0062 (0.0094)  loss_rpn_box_reg: 0.0038 (0.0066)  time: 0.2723  data: 0.0643  max mem: 1011
# Epoch: [14] Total time: 0:00:46 (0.2733 s / it)
# mAP:0.264
# 	AP at IoU level [0.50]: 0.506
# 	AP at IoU level [0.55]: 0.495
# 	AP at IoU level [0.60]: 0.439
# 	AP at IoU level [0.65]: 0.379
# 	AP at IoU level [0.70]: 0.311
# 	AP at IoU level [0.75]: 0.250
# 	AP at IoU level [0.80]: 0.167
# 	AP at IoU level [0.85]: 0.080
# 	AP at IoU level [0.90]: 0.018
# 	AP at IoU level [0.95]: 0.000
# Epoch: [15]  [  0/170]  eta: 0:00:50  lr: 0.000001  loss: 0.6554 (0.6554)  loss_classifier: 0.2512 (0.2512)  loss_box_reg: 0.3863 (0.3863)  loss_objectness: 0.0108 (0.0108)  loss_rpn_box_reg: 0.0070 (0.0070)  time: 0.2988  data: 0.0726  max mem: 1011
# Epoch: [15]  [ 20/170]  eta: 0:00:41  lr: 0.000001  loss: 0.4491 (0.4551)  loss_classifier: 0.1596 (0.1560)  loss_box_reg: 0.2757 (0.2871)  loss_objectness: 0.0060 (0.0068)  loss_rpn_box_reg: 0.0025 (0.0053)  time: 0.2738  data: 0.0602  max mem: 1011
# Epoch: [15]  [ 40/170]  eta: 0:00:36  lr: 0.000001  loss: 0.4191 (0.4715)  loss_classifier: 0.1502 (0.1641)  loss_box_reg: 0.2642 (0.2911)  loss_objectness: 0.0105 (0.0099)  loss_rpn_box_reg: 0.0063 (0.0064)  time: 0.2799  data: 0.0682  max mem: 1011
# Epoch: [15]  [ 60/170]  eta: 0:00:30  lr: 0.000001  loss: 0.5140 (0.4783)  loss_classifier: 0.1857 (0.1724)  loss_box_reg: 0.2806 (0.2900)  loss_objectness: 0.0089 (0.0099)  loss_rpn_box_reg: 0.0051 (0.0061)  time: 0.2699  data: 0.0642  max mem: 1011
# Epoch: [15]  [ 80/170]  eta: 0:00:24  lr: 0.000001  loss: 0.6044 (0.4980)  loss_classifier: 0.2082 (0.1790)  loss_box_reg: 0.3397 (0.3022)  loss_objectness: 0.0080 (0.0102)  loss_rpn_box_reg: 0.0071 (0.0067)  time: 0.2690  data: 0.0621  max mem: 1011
# Epoch: [15]  [100/170]  eta: 0:00:19  lr: 0.000001  loss: 0.3850 (0.4855)  loss_classifier: 0.1467 (0.1750)  loss_box_reg: 0.2451 (0.2943)  loss_objectness: 0.0062 (0.0099)  loss_rpn_box_reg: 0.0034 (0.0063)  time: 0.2688  data: 0.0605  max mem: 1011
# Epoch: [15]  [120/170]  eta: 0:00:13  lr: 0.000001  loss: 0.4839 (0.4877)  loss_classifier: 0.1575 (0.1764)  loss_box_reg: 0.2984 (0.2946)  loss_objectness: 0.0063 (0.0099)  loss_rpn_box_reg: 0.0035 (0.0068)  time: 0.2734  data: 0.0624  max mem: 1011
# Epoch: [15]  [140/170]  eta: 0:00:08  lr: 0.000001  loss: 0.4138 (0.4791)  loss_classifier: 0.1461 (0.1730)  loss_box_reg: 0.2579 (0.2897)  loss_objectness: 0.0060 (0.0097)  loss_rpn_box_reg: 0.0030 (0.0067)  time: 0.2720  data: 0.0628  max mem: 1011
# Epoch: [15]  [160/170]  eta: 0:00:02  lr: 0.000001  loss: 0.3997 (0.4749)  loss_classifier: 0.1385 (0.1715)  loss_box_reg: 0.2671 (0.2870)  loss_objectness: 0.0060 (0.0097)  loss_rpn_box_reg: 0.0044 (0.0068)  time: 0.2704  data: 0.0616  max mem: 1011
# Epoch: [15]  [169/170]  eta: 0:00:00  lr: 0.000001  loss: 0.4975 (0.4774)  loss_classifier: 0.1642 (0.1725)  loss_box_reg: 0.2877 (0.2885)  loss_objectness: 0.0080 (0.0097)  loss_rpn_box_reg: 0.0039 (0.0067)  time: 0.2745  data: 0.0613  max mem: 1011
# Epoch: [15] Total time: 0:00:46 (0.2726 s / it)
# mAP:0.272
# 	AP at IoU level [0.50]: 0.504
# 	AP at IoU level [0.55]: 0.490
# 	AP at IoU level [0.60]: 0.469
# 	AP at IoU level [0.65]: 0.406
# 	AP at IoU level [0.70]: 0.311
# 	AP at IoU level [0.75]: 0.253
# 	AP at IoU level [0.80]: 0.184
# 	AP at IoU level [0.85]: 0.083
# 	AP at IoU level [0.90]: 0.019
# 	AP at IoU level [0.95]: 0.000
# Epoch: [16]  [  0/170]  eta: 0:00:48  lr: 0.000000  loss: 0.7290 (0.7290)  loss_classifier: 0.2206 (0.2206)  loss_box_reg: 0.4934 (0.4934)  loss_objectness: 0.0085 (0.0085)  loss_rpn_box_reg: 0.0065 (0.0065)  time: 0.2877  data: 0.0630  max mem: 1011
# Epoch: [16]  [ 20/170]  eta: 0:00:40  lr: 0.000000  loss: 0.5511 (0.5776)  loss_classifier: 0.1918 (0.2138)  loss_box_reg: 0.3314 (0.3389)  loss_objectness: 0.0089 (0.0137)  loss_rpn_box_reg: 0.0052 (0.0112)  time: 0.2664  data: 0.0613  max mem: 1011
# Epoch: [16]  [ 40/170]  eta: 0:00:34  lr: 0.000000  loss: 0.4662 (0.5253)  loss_classifier: 0.1600 (0.1971)  loss_box_reg: 0.2692 (0.3078)  loss_objectness: 0.0047 (0.0118)  loss_rpn_box_reg: 0.0030 (0.0087)  time: 0.2689  data: 0.0607  max mem: 1011
# Epoch: [16]  [ 60/170]  eta: 0:00:29  lr: 0.000000  loss: 0.3805 (0.4835)  loss_classifier: 0.1322 (0.1779)  loss_box_reg: 0.2391 (0.2868)  loss_objectness: 0.0058 (0.0111)  loss_rpn_box_reg: 0.0032 (0.0077)  time: 0.2730  data: 0.0608  max mem: 1011
# Epoch: [16]  [ 80/170]  eta: 0:00:24  lr: 0.000000  loss: 0.4758 (0.4811)  loss_classifier: 0.1643 (0.1769)  loss_box_reg: 0.2719 (0.2862)  loss_objectness: 0.0085 (0.0105)  loss_rpn_box_reg: 0.0059 (0.0075)  time: 0.2825  data: 0.0630  max mem: 1011
# Epoch: [16]  [100/170]  eta: 0:00:19  lr: 0.000000  loss: 0.4455 (0.4730)  loss_classifier: 0.1534 (0.1723)  loss_box_reg: 0.2603 (0.2837)  loss_objectness: 0.0044 (0.0099)  loss_rpn_box_reg: 0.0036 (0.0070)  time: 0.2728  data: 0.0638  max mem: 1011
# Epoch: [16]  [120/170]  eta: 0:00:13  lr: 0.000000  loss: 0.4179 (0.4687)  loss_classifier: 0.1477 (0.1726)  loss_box_reg: 0.2437 (0.2791)  loss_objectness: 0.0076 (0.0100)  loss_rpn_box_reg: 0.0039 (0.0070)  time: 0.2712  data: 0.0613  max mem: 1011
# Epoch: [16]  [140/170]  eta: 0:00:08  lr: 0.000000  loss: 0.4516 (0.4658)  loss_classifier: 0.1301 (0.1686)  loss_box_reg: 0.2905 (0.2811)  loss_objectness: 0.0052 (0.0094)  loss_rpn_box_reg: 0.0032 (0.0067)  time: 0.2667  data: 0.0592  max mem: 1011
# Epoch: [16]  [160/170]  eta: 0:00:02  lr: 0.000000  loss: 0.4220 (0.4621)  loss_classifier: 0.1277 (0.1667)  loss_box_reg: 0.2616 (0.2791)  loss_objectness: 0.0052 (0.0095)  loss_rpn_box_reg: 0.0028 (0.0066)  time: 0.2710  data: 0.0618  max mem: 1011
# Epoch: [16]  [169/170]  eta: 0:00:00  lr: 0.000000  loss: 0.4060 (0.4602)  loss_classifier: 0.1277 (0.1657)  loss_box_reg: 0.2419 (0.2784)  loss_objectness: 0.0070 (0.0095)  loss_rpn_box_reg: 0.0028 (0.0066)  time: 0.2694  data: 0.0620  max mem: 1011
# Epoch: [16] Total time: 0:00:46 (0.2718 s / it)
# mAP:0.280
# 	AP at IoU level [0.50]: 0.518
# 	AP at IoU level [0.55]: 0.499
# 	AP at IoU level [0.60]: 0.475
# 	AP at IoU level [0.65]: 0.413
# 	AP at IoU level [0.70]: 0.326
# 	AP at IoU level [0.75]: 0.260
# 	AP at IoU level [0.80]: 0.198
# 	AP at IoU level [0.85]: 0.084
# 	AP at IoU level [0.90]: 0.028
# 	AP at IoU level [0.95]: 0.000
# Epoch: [17]  [  0/170]  eta: 0:01:00  lr: 0.000000  loss: 0.4495 (0.4495)  loss_classifier: 0.2424 (0.2424)  loss_box_reg: 0.1563 (0.1563)  loss_objectness: 0.0217 (0.0217)  loss_rpn_box_reg: 0.0291 (0.0291)  time: 0.3542  data: 0.0678  max mem: 1011
# Epoch: [17]  [ 20/170]  eta: 0:00:40  lr: 0.000000  loss: 0.4635 (0.4867)  loss_classifier: 0.1502 (0.1667)  loss_box_reg: 0.2889 (0.3056)  loss_objectness: 0.0075 (0.0087)  loss_rpn_box_reg: 0.0040 (0.0057)  time: 0.2683  data: 0.0598  max mem: 1011
# Epoch: [17]  [ 40/170]  eta: 0:00:35  lr: 0.000000  loss: 0.4742 (0.4928)  loss_classifier: 0.1748 (0.1745)  loss_box_reg: 0.2779 (0.3011)  loss_objectness: 0.0073 (0.0108)  loss_rpn_box_reg: 0.0039 (0.0065)  time: 0.2725  data: 0.0614  max mem: 1011
# Epoch: [17]  [ 60/170]  eta: 0:00:29  lr: 0.000000  loss: 0.5073 (0.4889)  loss_classifier: 0.1555 (0.1706)  loss_box_reg: 0.3148 (0.3019)  loss_objectness: 0.0068 (0.0102)  loss_rpn_box_reg: 0.0038 (0.0062)  time: 0.2663  data: 0.0610  max mem: 1011
# Epoch: [17]  [ 80/170]  eta: 0:00:24  lr: 0.000000  loss: 0.4446 (0.4872)  loss_classifier: 0.1425 (0.1705)  loss_box_reg: 0.2879 (0.2997)  loss_objectness: 0.0068 (0.0105)  loss_rpn_box_reg: 0.0037 (0.0066)  time: 0.2716  data: 0.0611  max mem: 1011
# Epoch: [17]  [100/170]  eta: 0:00:18  lr: 0.000000  loss: 0.4453 (0.4855)  loss_classifier: 0.1558 (0.1706)  loss_box_reg: 0.2827 (0.2980)  loss_objectness: 0.0066 (0.0103)  loss_rpn_box_reg: 0.0047 (0.0066)  time: 0.2731  data: 0.0602  max mem: 1011
# Epoch: [17]  [120/170]  eta: 0:00:13  lr: 0.000000  loss: 0.3864 (0.4764)  loss_classifier: 0.1374 (0.1691)  loss_box_reg: 0.2338 (0.2914)  loss_objectness: 0.0026 (0.0096)  loss_rpn_box_reg: 0.0023 (0.0064)  time: 0.2668  data: 0.0610  max mem: 1011
# Epoch: [17]  [140/170]  eta: 0:00:08  lr: 0.000000  loss: 0.4389 (0.4725)  loss_classifier: 0.1464 (0.1684)  loss_box_reg: 0.2647 (0.2883)  loss_objectness: 0.0042 (0.0094)  loss_rpn_box_reg: 0.0023 (0.0064)  time: 0.2650  data: 0.0612  max mem: 1011
# Epoch: [17]  [160/170]  eta: 0:00:02  lr: 0.000000  loss: 0.4352 (0.4743)  loss_classifier: 0.1641 (0.1704)  loss_box_reg: 0.2633 (0.2879)  loss_objectness: 0.0068 (0.0094)  loss_rpn_box_reg: 0.0038 (0.0066)  time: 0.2803  data: 0.0611  max mem: 1011
# Epoch: [17]  [169/170]  eta: 0:00:00  lr: 0.000000  loss: 0.4336 (0.4727)  loss_classifier: 0.1554 (0.1698)  loss_box_reg: 0.2513 (0.2869)  loss_objectness: 0.0076 (0.0094)  loss_rpn_box_reg: 0.0038 (0.0066)  time: 0.2764  data: 0.0644  max mem: 1011
# Epoch: [17] Total time: 0:00:46 (0.2711 s / it)
# mAP:0.276
# 	AP at IoU level [0.50]: 0.526
# 	AP at IoU level [0.55]: 0.500
# 	AP at IoU level [0.60]: 0.458
# 	AP at IoU level [0.65]: 0.383
# 	AP at IoU level [0.70]: 0.317
# 	AP at IoU level [0.75]: 0.261
# 	AP at IoU level [0.80]: 0.196
# 	AP at IoU level [0.85]: 0.089
# 	AP at IoU level [0.90]: 0.025
# 	AP at IoU level [0.95]: 0.000
# Epoch: [18]  [  0/170]  eta: 0:00:46  lr: 0.000000  loss: 0.5869 (0.5869)  loss_classifier: 0.1945 (0.1945)  loss_box_reg: 0.3766 (0.3766)  loss_objectness: 0.0087 (0.0087)  loss_rpn_box_reg: 0.0071 (0.0071)  time: 0.2747  data: 0.0485  max mem: 1011
# Epoch: [18]  [ 20/170]  eta: 0:00:41  lr: 0.000000  loss: 0.4866 (0.4876)  loss_classifier: 0.1543 (0.1562)  loss_box_reg: 0.3113 (0.3153)  loss_objectness: 0.0078 (0.0103)  loss_rpn_box_reg: 0.0053 (0.0059)  time: 0.2768  data: 0.0608  max mem: 1011
# Epoch: [18]  [ 40/170]  eta: 0:00:35  lr: 0.000000  loss: 0.3976 (0.4470)  loss_classifier: 0.1305 (0.1514)  loss_box_reg: 0.2245 (0.2809)  loss_objectness: 0.0059 (0.0095)  loss_rpn_box_reg: 0.0028 (0.0052)  time: 0.2687  data: 0.0613  max mem: 1011
# Epoch: [18]  [ 60/170]  eta: 0:00:30  lr: 0.000000  loss: 0.4865 (0.4729)  loss_classifier: 0.1729 (0.1625)  loss_box_reg: 0.3160 (0.2940)  loss_objectness: 0.0067 (0.0101)  loss_rpn_box_reg: 0.0043 (0.0063)  time: 0.2771  data: 0.0615  max mem: 1011
# Epoch: [18]  [ 80/170]  eta: 0:00:24  lr: 0.000000  loss: 0.4537 (0.4695)  loss_classifier: 0.1425 (0.1638)  loss_box_reg: 0.2770 (0.2881)  loss_objectness: 0.0079 (0.0102)  loss_rpn_box_reg: 0.0057 (0.0073)  time: 0.2720  data: 0.0593  max mem: 1011
# Epoch: [18]  [100/170]  eta: 0:00:19  lr: 0.000000  loss: 0.3816 (0.4612)  loss_classifier: 0.1505 (0.1632)  loss_box_reg: 0.2496 (0.2808)  loss_objectness: 0.0058 (0.0101)  loss_rpn_box_reg: 0.0037 (0.0072)  time: 0.2723  data: 0.0638  max mem: 1011
# Epoch: [18]  [120/170]  eta: 0:00:13  lr: 0.000000  loss: 0.4498 (0.4628)  loss_classifier: 0.1744 (0.1649)  loss_box_reg: 0.2658 (0.2810)  loss_objectness: 0.0051 (0.0099)  loss_rpn_box_reg: 0.0033 (0.0071)  time: 0.2717  data: 0.0638  max mem: 1011
# Epoch: [18]  [140/170]  eta: 0:00:08  lr: 0.000000  loss: 0.3350 (0.4537)  loss_classifier: 0.1343 (0.1618)  loss_box_reg: 0.2184 (0.2757)  loss_objectness: 0.0039 (0.0095)  loss_rpn_box_reg: 0.0024 (0.0067)  time: 0.2732  data: 0.0637  max mem: 1011
# Epoch: [18]  [160/170]  eta: 0:00:02  lr: 0.000000  loss: 0.4587 (0.4559)  loss_classifier: 0.1510 (0.1624)  loss_box_reg: 0.3021 (0.2779)  loss_objectness: 0.0062 (0.0092)  loss_rpn_box_reg: 0.0029 (0.0064)  time: 0.2629  data: 0.0607  max mem: 1011
# Epoch: [18]  [169/170]  eta: 0:00:00  lr: 0.000000  loss: 0.4865 (0.4607)  loss_classifier: 0.1889 (0.1649)  loss_box_reg: 0.3103 (0.2798)  loss_objectness: 0.0090 (0.0095)  loss_rpn_box_reg: 0.0056 (0.0067)  time: 0.2728  data: 0.0660  max mem: 1011
# Epoch: [18] Total time: 0:00:46 (0.2726 s / it)
# mAP:0.275
# 	AP at IoU level [0.50]: 0.528
# 	AP at IoU level [0.55]: 0.506
# 	AP at IoU level [0.60]: 0.462
# 	AP at IoU level [0.65]: 0.390
# 	AP at IoU level [0.70]: 0.312
# 	AP at IoU level [0.75]: 0.255
# 	AP at IoU level [0.80]: 0.185
# 	AP at IoU level [0.85]: 0.085
# 	AP at IoU level [0.90]: 0.029
# 	AP at IoU level [0.95]: 0.000
# Epoch: [19]  [  0/170]  eta: 0:00:50  lr: 0.000000  loss: 0.3551 (0.3551)  loss_classifier: 0.1141 (0.1141)  loss_box_reg: 0.2348 (0.2348)  loss_objectness: 0.0039 (0.0039)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 0.2955  data: 0.0683  max mem: 1011
# Epoch: [19]  [ 20/170]  eta: 0:00:40  lr: 0.000000  loss: 0.4634 (0.4400)  loss_classifier: 0.1389 (0.1546)  loss_box_reg: 0.2534 (0.2735)  loss_objectness: 0.0056 (0.0068)  loss_rpn_box_reg: 0.0021 (0.0051)  time: 0.2660  data: 0.0580  max mem: 1011
# Epoch: [19]  [ 40/170]  eta: 0:00:34  lr: 0.000000  loss: 0.4378 (0.4555)  loss_classifier: 0.1598 (0.1642)  loss_box_reg: 0.2681 (0.2766)  loss_objectness: 0.0081 (0.0081)  loss_rpn_box_reg: 0.0021 (0.0066)  time: 0.2700  data: 0.0609  max mem: 1011
# Epoch: [19]  [ 60/170]  eta: 0:00:29  lr: 0.000000  loss: 0.4575 (0.4669)  loss_classifier: 0.1703 (0.1709)  loss_box_reg: 0.2944 (0.2807)  loss_objectness: 0.0072 (0.0088)  loss_rpn_box_reg: 0.0041 (0.0066)  time: 0.2754  data: 0.0640  max mem: 1011
# Epoch: [19]  [ 80/170]  eta: 0:00:24  lr: 0.000000  loss: 0.4901 (0.4775)  loss_classifier: 0.1984 (0.1768)  loss_box_reg: 0.2941 (0.2838)  loss_objectness: 0.0076 (0.0097)  loss_rpn_box_reg: 0.0053 (0.0071)  time: 0.2696  data: 0.0616  max mem: 1011
# Epoch: [19]  [100/170]  eta: 0:00:19  lr: 0.000000  loss: 0.4160 (0.4676)  loss_classifier: 0.1385 (0.1709)  loss_box_reg: 0.2692 (0.2810)  loss_objectness: 0.0033 (0.0091)  loss_rpn_box_reg: 0.0037 (0.0066)  time: 0.2760  data: 0.0616  max mem: 1011
# Epoch: [19]  [120/170]  eta: 0:00:13  lr: 0.000000  loss: 0.4753 (0.4692)  loss_classifier: 0.1677 (0.1696)  loss_box_reg: 0.3084 (0.2833)  loss_objectness: 0.0074 (0.0094)  loss_rpn_box_reg: 0.0034 (0.0070)  time: 0.2773  data: 0.0618  max mem: 1011
# Epoch: [19]  [140/170]  eta: 0:00:08  lr: 0.000000  loss: 0.4648 (0.4675)  loss_classifier: 0.1621 (0.1682)  loss_box_reg: 0.2887 (0.2830)  loss_objectness: 0.0064 (0.0094)  loss_rpn_box_reg: 0.0031 (0.0069)  time: 0.2785  data: 0.0650  max mem: 1011
# Epoch: [19]  [160/170]  eta: 0:00:02  lr: 0.000000  loss: 0.4715 (0.4660)  loss_classifier: 0.1874 (0.1688)  loss_box_reg: 0.2780 (0.2811)  loss_objectness: 0.0078 (0.0094)  loss_rpn_box_reg: 0.0035 (0.0067)  time: 0.2717  data: 0.0611  max mem: 1011
# Epoch: [19]  [169/170]  eta: 0:00:00  lr: 0.000000  loss: 0.4643 (0.4651)  loss_classifier: 0.1651 (0.1679)  loss_box_reg: 0.2672 (0.2813)  loss_objectness: 0.0078 (0.0093)  loss_rpn_box_reg: 0.0031 (0.0066)  time: 0.2719  data: 0.0619  max mem: 1011
# Epoch: [19] Total time: 0:00:46 (0.2730 s / it)
# mAP:0.271
# 	AP at IoU level [0.50]: 0.523
# 	AP at IoU level [0.55]: 0.497
# 	AP at IoU level [0.60]: 0.455
# 	AP at IoU level [0.65]: 0.389
# 	AP at IoU level [0.70]: 0.299
# 	AP at IoU level [0.75]: 0.261
# 	AP at IoU level [0.80]: 0.177
# 	AP at IoU level [0.85]: 0.086
# 	AP at IoU level [0.90]: 0.028
# 	AP at IoU level [0.95]: 0.000

# %% [markdown]
# Saving the Model¶

# %%
from datetime import datetime
# Save model with current date
now = datetime.now()
d = now.strftime("%Y_%b_%d_%Hh_%mm")
PATH = 'model_'+d+'.pt'

# %%
torch.save(model.state_dict(), PATH)

# %% [markdown]
# Evaluate and Predict on Test Set

# %%
# Get saved model
model_eval = model.load_state_dict(torch.load(PATH))

# %%
# put the model in evaluation mode
model.eval()

# Evaluate the model
evaluate(model, loader_test, device=device)
# Out:
# mAP:0.338
# 	AP at IoU level [0.50]: 0.587
# 	AP at IoU level [0.55]: 0.573
# 	AP at IoU level [0.60]: 0.544
# 	AP at IoU level [0.65]: 0.491
# 	AP at IoU level [0.70]: 0.433
# 	AP at IoU level [0.75]: 0.353
# 	AP at IoU level [0.80]: 0.249
# 	AP at IoU level [0.85]: 0.121
# 	AP at IoU level [0.90]: 0.026
# 	AP at IoU level [0.95]: 0.000
# (0.3378088002322198,
#  [0.587427970660935,
#   0.5732048440098666,
#   0.5442963184816889,
#   0.4912365671689233,
#   0.4328205683139137,
#   0.35333041760518336,
#   0.24919484246120954,
#   0.1208086907761087,
#   0.02551018552300683,
#   0.0002575973213621465])

# %%
# Make prediction on random image
n = randint(30, dataset_test.len)
img, target = dataset_test[n]
with torch.no_grad():
    prediction = model([img.to(device)])[0]

# Non max suppression to reduce the number of bounding boxes
nms_prediction = apply_nms(prediction, iou_thresh=0.5)
# Remove low score boxes below score_thresh
filtered_prediction = remove_low_score_bb(nms_prediction, score_thresh=0.3)

# Draw bounding boxes
draw_bounding_boxes(img.detach().cpu(), target=target, prediction=filtered_prediction)
# Out:
# 267x400
# <PIL.Image.Image image mode=RGB size=267x400 at 0x7FD35C60C810>

# %%
from engine import evaluate as eval 
eval(model, loader_test, device=device)
# Out:
# creating index...
# index created!
# Test:  [ 0/38]  eta: 0:00:06  model_time: 0.1002 (0.1002)  evaluator_time: 0.0091 (0.0091)  time: 0.1587  data: 0.0477  max mem: 1011
# Test:  [37/38]  eta: 0:00:00  model_time: 0.1073 (0.1040)  evaluator_time: 0.0060 (0.0138)  time: 0.1689  data: 0.0578  max mem: 1011
# Test: Total time: 0:00:06 (0.1800 s / it)
# Averaged stats: model_time: 0.1073 (0.1040)  evaluator_time: 0.0060 (0.0138)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.278
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.521
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.264
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.177
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.397
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.236
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.372
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.386
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.234
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.748
